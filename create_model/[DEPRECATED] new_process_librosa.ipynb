# %%
# %load_ext cuml.accel
# %load_ext cudf.pandas
# Out:
# cuML: Accelerator installed.

# %%
import rmm
rmm.reinitialize(
    pool_allocator=True,
    initial_pool_size=20<<30,   # 20 GiB pool (tweak as you like)
    managed_memory=False
)
rmm.mr.set_current_device_resource(rmm.mr.ManagedMemoryResource())

# %%
import numpy as np
import pandas as pd
import sklearn as sk
import seaborn as sns
import matplotlib.pyplot as plt
import unicodedata
import warnings
import pickle
import logging
import librosa
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# Now that we have our imports, we want to import the data. This will be seen as de-pickling the Songs.pkl file, import to a DataFrame, and then accessing each song.

# %%
# load df
Songs = []
with open("/home/tyler/Downloads/kpop_project/create_model/local_Songs.pkl", 'rb') as f:
    Songs = pickle.load(f) 
data = [vars(song) for song in Songs]
df = pd.DataFrame(data)
df
# Out:
#                                                    path company generation  \
# 0     /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...     JYP          1
# 1     /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...     JYP          1
# 2     /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...     JYP          1
# 3     /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...     JYP          1
# 4     /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...     JYP          1
# ...                                                 ...     ...        ...
# 5522  /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...      YG          5
# 5523  /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...      YG          5
# 5524  /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...      YG          5
# 5525  /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...      YG          5
# 5526  /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...      YG          5
#
#            artist                               name
# 0           g.o.d                             0%.mp3
# 1           g.o.d                         134-14.mp3
# 2           g.o.d                             20.mp3
# 3           g.o.d                     21C 우리의 희망.mp3
# 4           g.o.d                     5+4+1+5=15.mp3
# ...           ...                                ...
# 5522  BabyMonster                         SHEESH.mp3
# 5523  BabyMonster   Stuck In The Middle (7 ver.).mp3
# 5524  BabyMonster    Stuck In The Middle (Remix).mp3
# 5525  BabyMonster            Stuck In The Middle.mp3
# 5526  BabyMonster  Woke Up In Tokyo (RUKA & ASA).mp3
#
# [5527 rows x 5 columns]

# %%
# need some logging to make skip work already done and to find failures
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s — %(levelname)s — %(message)s",
    handlers=[
        logging.FileHandler("/home/tyler/Downloads/kpop_project/logs/new_process_librosa.log"),
        logging.StreamHandler()
    ]
)

# %%
def process_librosa(audio, sr):
    # Extract MFCC features using librosa
    mfccs = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=13)
    mfccs_mean = np.mean(mfccs.T, axis=0)  # Get mean of MFCC features

    # Chroma features
    chroma = librosa.feature.chroma_stft(y=audio, sr=sr)
    chroma_mean = np.mean(chroma.T, axis=0)

    # Spectral Contrast
    spectral_contrast = librosa.feature.spectral_contrast(y=audio, sr=sr)
    spectral_contrast_mean = np.mean(spectral_contrast.T, axis=0)

    # Zero-Crossing Rate
    zcr = librosa.feature.zero_crossing_rate(y=audio)
    zcr_mean = np.mean(zcr.T, axis=0)

    # Root Mean Square Energy
    rmse = librosa.feature.rms(y=audio)
    rmse_mean = np.mean(rmse.T, axis=0)

    # Spectral Centroid
    spectral_centroid = librosa.feature.spectral_centroid(y=audio, sr=sr)
    spectral_centroid_mean = np.mean(spectral_centroid.T, axis=0)

    # Spectral Bandwidth
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=audio, sr=sr)
    spectral_bandwidth_mean = np.mean(spectral_bandwidth.T, axis=0)

    # Spectral Flatness
    spectral_flatness = librosa.feature.spectral_flatness(y=audio)
    spectral_flatness_mean = np.mean(spectral_flatness.T, axis=0)

    # Tonnetz
    tonnetz = librosa.feature.tonnetz(y=audio, sr=sr)
    tonnetz_mean = np.mean(tonnetz.T, axis=0)

    # Combine features into a single feature vector
    features = np.concatenate((
        mfccs_mean, chroma_mean, spectral_contrast_mean,
        zcr_mean, rmse_mean, spectral_centroid_mean,
        spectral_bandwidth_mean, spectral_flatness_mean,
        tonnetz_mean
    ))
    return features

# %%
# # split songs into clips
# clip_duration = 30
# overlap = 10
# x_out = "/home/tyler/gdrive/K-pop Project 2024-5/K-pop Project/ML_inputs/features.pkl" 
# X = pickle.load(open(x_out, 'rb'))
# # X = []
# labels_out = "/home/tyler/gdrive/K-pop Project 2024-5/K-pop Project/ML_inputs/labels.pkl"
# labels = pickle.load(open(labels_out, 'rb'))
# # labels = []
# seen_out = "/home/tyler/gdrive/K-pop Project 2024-5/K-pop Project/ML_inputs/seen.pkl"
# seen = pickle.load(open(seen_out, 'rb'))
# # seen = set()
# completed = 0
# for row in df.itertuples():
#     if row.path in seen:
#         logging.info(f"Skipping {row.name} - {row.artist}, already processed.")
#         completed += 1
#     else:
#         # creates 30-second clips of audio with 10 seconds of audio; removes clips that are less than 30 seconds at the end (loses at most 9 seconds at the end)
#         y, sr = librosa.load(unicodedata.normalize('NFC', row.path))
#         clip_length = clip_duration * sr
#         hop_length = int(clip_length *(1 - (float(overlap) / clip_duration)))
#         end_spot = int(len(y) - clip_length + 1)
#         for start_sample in range(0, end_spot, hop_length):
#             clip = y[start_sample:start_sample + clip_length]
#             features = process_librosa(clip, sr)
#             # Append features and corresponding label
#             X.append(features)  # Append to list
#             labels.append(int(row.generation))
#         seen.add(row.path)
#         # keyboard interrupts will only occur before serializing processed data or after, never in the middle 
#         try:
#             pickle.dump(X, open(x_out, 'wb'))
#             pickle.dump(labels, open(labels_out, 'wb'))
#             pickle.dump(seen, open(seen_out, 'wb'))
#             completed += 1
#             logging.info(f"Processed and saved features for {row.name} - {row.artist}. {df.shape[0] - completed} songs remaining.")
#         except KeyboardInterrupt:
#             # Ignore Ctrl+C during vital section
#             print("KeyboardInterrupt ignored in vital section")

# %%
def company_to_int(company: str):
    if company == 'JYP':
        return 7
    elif company == 'SM':
        return 9
    else: # YG
        return 11

# %%
df['path'] = df['path'].str.replace('/home/tyler/gdrive/K-pop Project 2024-5/K-pop Project/music_files', '/home/tyler/Downloads/kpop_project/music_files')

# %%
# create company labels for the features

# split songs into clips
clip_duration = 30
overlap = 10

company_labels_out = "/home/tyler/Downloads/kpop_project/ML_inputs/company_labels.pkl"
# company_labels = pickle.load(open(labels_out, 'rb'))
company_labels = []
seen_out = "/home/tyler/Downloads/kpop_project/ML_inputs/company_label_creation_seen.pkl"
# seen = pickle.load(open(seen_out, 'rb'))
seen = set()
completed = 0
for row in df.itertuples():
    if row.path in seen:
        logging.info(f"Skipping {row.name} - {row.artist}, already processed company label.")
        completed += 1
    else:
        # creates 30-second clips of audio with 10 seconds of audio; removes clips that are less than 30 seconds at the end (loses at most 9 seconds at the end)
        y, sr = librosa.load(unicodedata.normalize('NFC', row.path))
        clip_length = clip_duration * sr
        hop_length = int(clip_length *(1 - (float(overlap) / clip_duration)))
        end_spot = int(len(y) - clip_length + 1)
        for start_sample in range(0, end_spot, hop_length):            
            company_labels.append(company_to_int(row.company))
        seen.add(row.path)
        # keyboard interrupts will only occur before serializing processed data or after, never in the middle 
        try:
            logging.info(f"Saving company labels for {row.name} - {row.artist}.")
            pickle.dump(company_labels, open(company_labels_out, 'wb'))
            pickle.dump(seen, open(seen_out, 'wb'))
            completed += 1
            logging.info(f"Processed and saved company labels for {row.name} - {row.artist}. {df.shape[0] - completed} songs remaining.")
        except KeyboardInterrupt:
            # Ignore Ctrl+C during vital section
            print("KeyboardInterrupt ignored in vital section")
# Out:
# 2025-06-27 15:35:24,933 — INFO — Saving company labels for 0%.mp3 - g.o.d.
# 2025-06-27 15:35:24,946 — INFO — Processed and saved company labels for 0%.mp3 - g.o.d. 5526 songs remaining.
# 2025-06-27 15:35:25,249 — INFO — Saving company labels for 134-14.mp3 - g.o.d.
# 2025-06-27 15:35:25,250 — INFO — Processed and saved company labels for 134-14.mp3 - g.o.d. 5525 songs remaining.
# 2025-06-27 15:35:25,420 — INFO — Saving company labels for 20.mp3 - g.o.d.
# 2025-06-27 15:35:25,422 — INFO — Processed and saved company labels for 20.mp3 - g.o.d. 5524 songs remaining.
# 2025-06-27 15:35:25,781 — INFO — Saving company labels for 21C 우리의 희망.mp3 - g.o.d.
# 2025-06-27 15:35:25,783 — INFO — Processed and saved company labels for 21C 우리의 희망.mp3 - g.o.d. 5523 songs remaining.
# 2025-06-27 15:35:26,218 — INFO — Saving company labels for 5+4+1+5=15.mp3 - g.o.d.
# 2025-06-27 15:35:26,220 — INFO — Processed and saved company labels for 5+4+1+5=15.mp3 - g.o.d. 5522 songs remaining.
# 2025-06-27 15:35:26,402 — INFO — Saving company labels for 5집을 내며.mp3 - g.o.d.
# 2025-06-27 15:35:26,403 — INFO — Processed and saved company labels for 5집을 내며.mp3 - g.o.d. 5521 songs remaining.
# 2025-06-27 15:35:26,774 — INFO — Saving company labels for A Funny But Sad Day (웃픈 하루) (Inst.).mp3 - g.o.d.
# 2025-06-27 15:35:26,777 — INFO — Processed and saved company labels for A Funny But Sad Day (웃픈 하루) (Inst.).mp3 - g.o.d. 5520 songs remaining.
# 2025-06-27 15:35:27,144 — INFO — Saving company labels for A Funny But Sad Day (웃픈 하루).mp3 - g.o.d.
# 2025-06-27 15:35:27,145 — INFO — Processed and saved company labels for A Funny But Sad Day (웃픈 하루).mp3 - g.o.d. 5519 songs remaining.
# 2025-06-27 15:35:27,534 — INFO — Saving company labels for An Ordinary Day (보통날) (Original Ver.).mp3 - g.o.d.
# 2025-06-27 15:35:27,536 — INFO — Processed and saved company labels for An Ordinary Day (보통날) (Original Ver.).mp3 - g.o.d. 5518 songs remaining.
# 2025-06-27 15:35:27,887 — INFO — Saving company labels for Confession (Instrumental) (지금 만나러 갈게 (Inst.)).mp3 - g.o.d.
# 2025-06-27 15:35:27,889 — INFO — Processed and saved company labels for Confession (Instrumental) (지금 만나러 갈게 (Inst.)).mp3 - g.o.d. 5517 songs remaining.
# 2025-06-27 15:35:28,250 — INFO — Saving company labels for Confession (지금 만나러 갈게).mp3 - g.o.d.
# 2025-06-27 15:35:28,251 — INFO — Processed and saved company labels for Confession (지금 만나러 갈게).mp3 - g.o.d. 5516 songs remaining.
# 2025-06-27 15:35:28,576 — INFO — Saving company labels for Dance All Night.mp3 - g.o.d.
# 2025-06-27 15:35:28,578 — INFO — Processed and saved company labels for Dance All Night.mp3 - g.o.d. 5515 songs remaining.
# 2025-06-27 15:35:28,882 — INFO — Saving company labels for Dance all night (Dance all night).mp3 - g.o.d.
# 2025-06-27 15:35:28,884 — INFO — Processed and saved company labels for Dance all night (Dance all night).mp3 - g.o.d. 5514 songs remaining.
# 2025-06-27 15:35:29,066 — INFO — Saving company labels for Exit, 20The Century-Enter The 21St.mp3 - g.o.d.
# 2025-06-27 15:35:29,068 — INFO — Processed and saved company labels for Exit, 20The Century-Enter The 21St.mp3 - g.o.d. 5513 songs remaining.
# 2025-06-27 15:35:29,440 — INFO — Saving company labels for Eye To Eye (눈을 맞춰).mp3 - g.o.d.
# 2025-06-27 15:35:29,441 — INFO — Processed and saved company labels for Eye To Eye (눈을 맞춰).mp3 - g.o.d. 5512 songs remaining.
# 2025-06-27 15:35:29,581 — INFO — Saving company labels for Five Men and a Kiddo (아저씨와 메건리).mp3 - g.o.d.
# 2025-06-27 15:35:29,583 — INFO — Processed and saved company labels for Five Men and a Kiddo (아저씨와 메건리).mp3 - g.o.d. 5511 songs remaining.
# 2025-06-27 15:35:29,920 — INFO — Saving company labels for Friday Night.mp3 - g.o.d.
# 2025-06-27 15:35:29,922 — INFO — Processed and saved company labels for Friday Night.mp3 - g.o.d. 5510 songs remaining.
# 2025-06-27 15:35:30,359 — INFO — Saving company labels for Friday night (Friday night).mp3 - g.o.d.
# 2025-06-27 15:35:30,361 — INFO — Processed and saved company labels for Friday night (Friday night).mp3 - g.o.d. 5509 songs remaining.
# 2025-06-27 15:35:30,649 — INFO — Saving company labels for G'swag (신사의 품격).mp3 - g.o.d.
# 2025-06-27 15:35:30,650 — INFO — Processed and saved company labels for G'swag (신사의 품격).mp3 - g.o.d. 5508 songs remaining.
# 2025-06-27 15:35:30,952 — INFO — Saving company labels for God 파티.mp3 - g.o.d.
# 2025-06-27 15:35:30,954 — INFO — Processed and saved company labels for God 파티.mp3 - g.o.d. 5507 songs remaining.
# 2025-06-27 15:35:31,206 — INFO — Saving company labels for I Know (나는 알아) (Prod. Joon Park) (박준형).mp3 - g.o.d.
# 2025-06-27 15:35:31,208 — INFO — Processed and saved company labels for I Know (나는 알아) (Prod. Joon Park) (박준형).mp3 - g.o.d. 5506 songs remaining.
# 2025-06-27 15:35:31,516 — INFO — Saving company labels for I Like It (난 좋아).mp3 - g.o.d.
# 2025-06-27 15:35:31,518 — INFO — Processed and saved company labels for I Like It (난 좋아).mp3 - g.o.d. 5505 songs remaining.
# 2025-06-27 15:35:31,634 — INFO — Saving company labels for Intro.mp3 - g.o.d.
# 2025-06-27 15:35:31,637 — INFO — Processed and saved company labels for Intro.mp3 - g.o.d. 5504 songs remaining.
# 2025-06-27 15:35:31,952 — INFO — Saving company labels for Leave Him (그 남자를 떠나).mp3 - g.o.d.
# 2025-06-27 15:35:31,953 — INFO — Processed and saved company labels for Leave Him (그 남자를 떠나).mp3 - g.o.d. 5503 songs remaining.
# 2025-06-27 15:35:32,307 — INFO — Saving company labels for Loving You.mp3 - g.o.d.
# 2025-06-27 15:35:32,310 — INFO — Processed and saved company labels for Loving You.mp3 - g.o.d. 5502 songs remaining.
# 2025-06-27 15:35:32,443 — INFO — Saving company labels for MENT 1 (MENT 1).mp3 - g.o.d.
# 2025-06-27 15:35:32,444 — INFO — Processed and saved company labels for MENT 1 (MENT 1).mp3 - g.o.d. 5501 songs remaining.
# 2025-06-27 15:35:32,935 — INFO — Saving company labels for MENT 2 (MENT 2).mp3 - g.o.d.
# 2025-06-27 15:35:32,937 — INFO — Processed and saved company labels for MENT 2 (MENT 2).mp3 - g.o.d. 5500 songs remaining.
# 2025-06-27 15:35:33,297 — INFO — Saving company labels for Not Knowing (모르죠) (Prod. Son Ho Young) (손호영).mp3 - g.o.d.
# 2025-06-27 15:35:33,299 — INFO — Processed and saved company labels for Not Knowing (모르죠) (Prod. Son Ho Young) (손호영).mp3 - g.o.d. 5499 songs remaining.
# 2025-06-27 15:35:33,724 — INFO — Saving company labels for OPENING MENT (OPENING MENT).mp3 - g.o.d.
# 2025-06-27 15:35:33,726 — INFO — Processed and saved company labels for OPENING MENT (OPENING MENT).mp3 - g.o.d. 5498 songs remaining.
# 2025-06-27 15:35:34,015 — INFO — Saving company labels for Report To The Dance Floor.mp3 - g.o.d.
# 2025-06-27 15:35:34,016 — INFO — Processed and saved company labels for Report To The Dance Floor.mp3 - g.o.d. 5497 songs remaining.
# 2025-06-27 15:35:34,423 — INFO — Saving company labels for Road (길) (song by IU) (아이유) , Henry (헨리) , Jo Hyunah (조현아) , Yang Da Il....mp3 - g.o.d.
# 2025-06-27 15:35:34,424 — INFO — Processed and saved company labels for Road (길) (song by IU) (아이유) , Henry (헨리) , Jo Hyunah (조현아) , Yang Da Il....mp3 - g.o.d. 5496 songs remaining.
# 2025-06-27 15:35:34,756 — INFO — Saving company labels for Saturday Night (Inst.).mp3 - g.o.d.
# 2025-06-27 15:35:34,757 — INFO — Processed and saved company labels for Saturday Night (Inst.).mp3 - g.o.d. 5495 songs remaining.
# 2025-06-27 15:35:35,079 — INFO — Saving company labels for Saturday Night.mp3 - g.o.d.
# 2025-06-27 15:35:35,081 — INFO — Processed and saved company labels for Saturday Night.mp3 - g.o.d. 5494 songs remaining.
# 2025-06-27 15:35:35,387 — INFO — Saving company labels for Say God.mp3 - g.o.d.
# 2025-06-27 15:35:35,388 — INFO — Processed and saved company labels for Say God.mp3 - g.o.d. 5493 songs remaining.
# 2025-06-27 15:35:35,698 — INFO — Saving company labels for Say god (Say god).mp3 - g.o.d.
# 2025-06-27 15:35:35,700 — INFO — Processed and saved company labels for Say god (Say god).mp3 - g.o.d. 5492 songs remaining.
# 2025-06-27 15:35:36,076 — INFO — Saving company labels for Sing for Me (노래 불러줘요) (feat. IU) (아이유).mp3 - g.o.d.
# 2025-06-27 15:35:36,077 — INFO — Processed and saved company labels for Sing for Me (노래 불러줘요) (feat. IU) (아이유).mp3 - g.o.d. 5491 songs remaining.
# 2025-06-27 15:35:36,422 — INFO — Saving company labels for Sky Blue Promise (하늘색 약속).mp3 - g.o.d.
# 2025-06-27 15:35:36,424 — INFO — Processed and saved company labels for Sky Blue Promise (하늘색 약속).mp3 - g.o.d. 5490 songs remaining.
# 2025-06-27 15:35:36,770 — INFO — Saving company labels for Smile.mp3 - g.o.d.
# 2025-06-27 15:35:36,771 — INFO — Processed and saved company labels for Smile.mp3 - g.o.d. 5489 songs remaining.
# 2025-06-27 15:35:37,101 — INFO — Saving company labels for Snowfall (눈이 내린다) (inst.).mp3 - g.o.d.
# 2025-06-27 15:35:37,102 — INFO — Processed and saved company labels for Snowfall (눈이 내린다) (inst.).mp3 - g.o.d. 5488 songs remaining.
# 2025-06-27 15:35:37,421 — INFO — Saving company labels for Snowfall (눈이 내린다).mp3 - g.o.d.
# 2025-06-27 15:35:37,422 — INFO — Processed and saved company labels for Snowfall (눈이 내린다).mp3 - g.o.d. 5487 songs remaining.
# 2025-06-27 15:35:37,716 — INFO — Saving company labels for So You Can Come Back to Me (니가 다시 돌아올 수 있도록) (Prod. Yoon Kye Sang)....mp3 - g.o.d.
# 2025-06-27 15:35:37,717 — INFO — Processed and saved company labels for So You Can Come Back to Me (니가 다시 돌아올 수 있도록) (Prod. Yoon Kye Sang)....mp3 - g.o.d. 5486 songs remaining.
# 2025-06-27 15:35:38,010 — INFO — Saving company labels for Stand Up.mp3 - g.o.d.
# 2025-06-27 15:35:38,012 — INFO — Processed and saved company labels for Stand Up.mp3 - g.o.d. 5485 songs remaining.
# 2025-06-27 15:35:38,415 — INFO — Saving company labels for The Lone Duckling (미운오리새끼) (Inst.).mp3 - g.o.d.
# 2025-06-27 15:35:38,416 — INFO — Processed and saved company labels for The Lone Duckling (미운오리새끼) (Inst.).mp3 - g.o.d. 5484 songs remaining.
# 2025-06-27 15:35:38,792 — INFO — Saving company labels for The Lone Duckling (미운오리새끼).mp3 - g.o.d.
# 2025-06-27 15:35:38,794 — INFO — Processed and saved company labels for The Lone Duckling (미운오리새끼).mp3 - g.o.d. 5483 songs remaining.
# 2025-06-27 15:35:39,187 — INFO — Saving company labels for The Story of Our Lives (우리가 사는 이야기) (Inst.).mp3 - g.o.d.
# 2025-06-27 15:35:39,188 — INFO — Processed and saved company labels for The Story of Our Lives (우리가 사는 이야기) (Inst.).mp3 - g.o.d. 5482 songs remaining.
# 2025-06-27 15:35:39,577 — INFO — Saving company labels for The Story of Our Lives (우리가 사는 이야기) (feat. Megan Lee) (메건리).mp3 - g.o.d.
# 2025-06-27 15:35:39,578 — INFO — Processed and saved company labels for The Story of Our Lives (우리가 사는 이야기) (feat. Megan Lee) (메건리).mp3 - g.o.d. 5481 songs remaining.
# 2025-06-27 15:35:39,918 — INFO — Saving company labels for The Things You Need to Do (네가 할 일) (Inst.).mp3 - g.o.d.
# 2025-06-27 15:35:39,919 — INFO — Processed and saved company labels for The Things You Need to Do (네가 할 일) (Inst.).mp3 - g.o.d. 5480 songs remaining.
# 2025-06-27 15:35:40,246 — INFO — Saving company labels for The Things You Need to Do (네가 할 일).mp3 - g.o.d.
# 2025-06-27 15:35:40,248 — INFO — Processed and saved company labels for The Things You Need to Do (네가 할 일).mp3 - g.o.d. 5479 songs remaining.
# 2025-06-27 15:35:40,566 — INFO — Saving company labels for Tonight.mp3 - g.o.d.
# 2025-06-27 15:35:40,568 — INFO — Processed and saved company labels for Tonight.mp3 - g.o.d. 5478 songs remaining.
# 2025-06-27 15:35:40,820 — INFO — Saving company labels for Where you Belong (니가 있어야 할 곳) (Prod. Kim Tae Woo) (김태우).mp3 - g.o.d.
# 2025-06-27 15:35:40,822 — INFO — Processed and saved company labels for Where you Belong (니가 있어야 할 곳) (Prod. Kim Tae Woo) (김태우).mp3 - g.o.d. 5477 songs remaining.
# 2025-06-27 15:35:41,198 — INFO — Saving company labels for Why (왜) (Prod. Danny Ahn) (데니안).mp3 - g.o.d.
# 2025-06-27 15:35:41,199 — INFO — Processed and saved company labels for Why (왜) (Prod. Danny Ahn) (데니안).mp3 - g.o.d. 5476 songs remaining.
# 2025-06-27 15:35:41,545 — INFO — Saving company labels for Wind (바람) (Inst.).mp3 - g.o.d.
# 2025-06-27 15:35:41,547 — INFO — Processed and saved company labels for Wind (바람) (Inst.).mp3 - g.o.d. 5475 songs remaining.
# 2025-06-27 15:35:41,901 — INFO — Saving company labels for Wind (바람).mp3 - g.o.d.
# 2025-06-27 15:35:41,902 — INFO — Processed and saved company labels for Wind (바람).mp3 - g.o.d. 5474 songs remaining.
# 2025-06-27 15:35:42,163 — INFO — Saving company labels for champion title song (champion title song).mp3 - g.o.d.
# 2025-06-27 15:35:42,164 — INFO — Processed and saved company labels for champion title song (champion title song).mp3 - g.o.d. 5473 songs remaining.
# 2025-06-27 15:35:42,515 — INFO — Saving company labels for 가자.mp3 - g.o.d.
# 2025-06-27 15:35:42,517 — INFO — Processed and saved company labels for 가자.mp3 - g.o.d. 5472 songs remaining.
# 2025-06-27 15:35:42,894 — INFO — Saving company labels for 거짓말 (거짓말).mp3 - g.o.d.
# 2025-06-27 15:35:42,896 — INFO — Processed and saved company labels for 거짓말 (거짓말).mp3 - g.o.d. 5471 songs remaining.
# 2025-06-27 15:35:43,233 — INFO — Saving company labels for 거짓말.mp3 - g.o.d.
# 2025-06-27 15:35:43,234 — INFO — Processed and saved company labels for 거짓말.mp3 - g.o.d. 5470 songs remaining.
# 2025-06-27 15:35:43,670 — INFO — Saving company labels for 걸어선 안되는 전화.mp3 - g.o.d.
# 2025-06-27 15:35:43,672 — INFO — Processed and saved company labels for 걸어선 안되는 전화.mp3 - g.o.d. 5469 songs remaining.
# 2025-06-27 15:35:43,800 — INFO — Saving company labels for 계상 MENT (계상 MENT).mp3 - g.o.d.
# 2025-06-27 15:35:43,802 — INFO — Processed and saved company labels for 계상 MENT (계상 MENT).mp3 - g.o.d. 5468 songs remaining.
# 2025-06-27 15:35:44,144 — INFO — Saving company labels for 관찰 (관찰).mp3 - g.o.d.
# 2025-06-27 15:35:44,145 — INFO — Processed and saved company labels for 관찰 (관찰).mp3 - g.o.d. 5467 songs remaining.
# 2025-06-27 15:35:44,548 — INFO — Saving company labels for 그대 날 떠난 후로 (그대 날 떠난 후로).mp3 - g.o.d.
# 2025-06-27 15:35:44,549 — INFO — Processed and saved company labels for 그대 날 떠난 후로 (그대 날 떠난 후로).mp3 - g.o.d. 5466 songs remaining.
# 2025-06-27 15:35:44,907 — INFO — Saving company labels for 그대 날 떠난 후로.mp3 - g.o.d.
# 2025-06-27 15:35:44,909 — INFO — Processed and saved company labels for 그대 날 떠난 후로.mp3 - g.o.d. 5465 songs remaining.
# 2025-06-27 15:35:45,319 — INFO — Saving company labels for 기차.mp3 - g.o.d.
# 2025-06-27 15:35:45,321 — INFO — Processed and saved company labels for 기차.mp3 - g.o.d. 5464 songs remaining.
# 2025-06-27 15:35:45,714 — INFO — Saving company labels for 기회를 줘.mp3 - g.o.d.
# 2025-06-27 15:35:45,716 — INFO — Processed and saved company labels for 기회를 줘.mp3 - g.o.d. 5463 songs remaining.
# 2025-06-27 15:35:46,046 — INFO — Saving company labels for 길 (Instrumental).mp3 - g.o.d.
# 2025-06-27 15:35:46,047 — INFO — Processed and saved company labels for 길 (Instrumental).mp3 - g.o.d. 5462 songs remaining.
# 2025-06-27 15:35:46,408 — INFO — Saving company labels for 길.mp3 - g.o.d.
# 2025-06-27 15:35:46,410 — INFO — Processed and saved company labels for 길.mp3 - g.o.d. 5461 songs remaining.
# 2025-06-27 15:35:46,821 — INFO — Saving company labels for 꿈이었으면 If It Were a Dream (feat. Sweet Sorrow).mp3 - g.o.d.
# 2025-06-27 15:35:46,822 — INFO — Processed and saved company labels for 꿈이었으면 If It Were a Dream (feat. Sweet Sorrow).mp3 - g.o.d. 5460 songs remaining.
# 2025-06-27 15:35:47,185 — INFO — Saving company labels for 나는 알아.mp3 - g.o.d.
# 2025-06-27 15:35:47,187 — INFO — Processed and saved company labels for 나는 알아.mp3 - g.o.d. 5459 songs remaining.
# 2025-06-27 15:35:47,524 — INFO — Saving company labels for 나와 함께 춤을 춰.mp3 - g.o.d.
# 2025-06-27 15:35:47,526 — INFO — Processed and saved company labels for 나와 함께 춤을 춰.mp3 - g.o.d. 5458 songs remaining.
# 2025-06-27 15:35:47,863 — INFO — Saving company labels for 난 남자가 있어 (With김정은).mp3 - g.o.d.
# 2025-06-27 15:35:47,865 — INFO — Processed and saved company labels for 난 남자가 있어 (With김정은).mp3 - g.o.d. 5457 songs remaining.
# 2025-06-27 15:35:48,238 — INFO — Saving company labels for 난 사랑을 몰라 (난 사랑을 몰라).mp3 - g.o.d.
# 2025-06-27 15:35:48,239 — INFO — Processed and saved company labels for 난 사랑을 몰라 (난 사랑을 몰라).mp3 - g.o.d. 5456 songs remaining.
# 2025-06-27 15:35:48,608 — INFO — Saving company labels for 난 사랑을 몰라.mp3 - g.o.d.
# 2025-06-27 15:35:48,609 — INFO — Processed and saved company labels for 난 사랑을 몰라.mp3 - g.o.d. 5455 songs remaining.
# 2025-06-27 15:35:48,987 — INFO — Saving company labels for 날 기다려줘 (날 기다려줘).mp3 - g.o.d.
# 2025-06-27 15:35:48,989 — INFO — Processed and saved company labels for 날 기다려줘 (날 기다려줘).mp3 - g.o.d. 5454 songs remaining.
# 2025-06-27 15:35:49,315 — INFO — Saving company labels for 눈치 없는 눈물.mp3 - g.o.d.
# 2025-06-27 15:35:49,316 — INFO — Processed and saved company labels for 눈치 없는 눈물.mp3 - g.o.d. 5453 songs remaining.
# 2025-06-27 15:35:49,686 — INFO — Saving company labels for 니가 다시 돌아올수 있도록 (니가 다시 돌아올수 있도록).mp3 - g.o.d.
# 2025-06-27 15:35:49,687 — INFO — Processed and saved company labels for 니가 다시 돌아올수 있도록 (니가 다시 돌아올수 있도록).mp3 - g.o.d. 5452 songs remaining.
# 2025-06-27 15:35:49,997 — INFO — Saving company labels for 니가 있어야 할 곳.mp3 - g.o.d.
# 2025-06-27 15:35:49,998 — INFO — Processed and saved company labels for 니가 있어야 할 곳.mp3 - g.o.d. 5451 songs remaining.
# 2025-06-27 15:35:50,390 — INFO — Saving company labels for 니가 필요해 (니가 필요해).mp3 - g.o.d.
# 2025-06-27 15:35:50,392 — INFO — Processed and saved company labels for 니가 필요해 (니가 필요해).mp3 - g.o.d. 5450 songs remaining.
# 2025-06-27 15:35:50,685 — INFO — Saving company labels for 니가 필요해.mp3 - g.o.d.
# 2025-06-27 15:35:50,686 — INFO — Processed and saved company labels for 니가 필요해.mp3 - g.o.d. 5449 songs remaining.
# 2025-06-27 15:35:50,938 — INFO — Saving company labels for 다섯 남자 이야기.mp3 - g.o.d.
# 2025-06-27 15:35:50,939 — INFO — Processed and saved company labels for 다섯 남자 이야기.mp3 - g.o.d. 5448 songs remaining.
# 2025-06-27 15:35:51,384 — INFO — Saving company labels for 다시.mp3 - g.o.d.
# 2025-06-27 15:35:51,386 — INFO — Processed and saved company labels for 다시.mp3 - g.o.d. 5447 songs remaining.
# 2025-06-27 15:35:51,736 — INFO — Saving company labels for 더듬고 있어.mp3 - g.o.d.
# 2025-06-27 15:35:51,738 — INFO — Processed and saved company labels for 더듬고 있어.mp3 - g.o.d. 5446 songs remaining.
# 2025-06-27 15:35:51,968 — INFO — Saving company labels for 데니 MENT (데니 MENT).mp3 - g.o.d.
# 2025-06-27 15:35:51,970 — INFO — Processed and saved company labels for 데니 MENT (데니 MENT).mp3 - g.o.d. 5445 songs remaining.
# 2025-06-27 15:35:52,422 — INFO — Saving company labels for 돌아와줘 (돌아와줘).mp3 - g.o.d.
# 2025-06-27 15:35:52,423 — INFO — Processed and saved company labels for 돌아와줘 (돌아와줘).mp3 - g.o.d. 5444 songs remaining.
# 2025-06-27 15:35:52,792 — INFO — Saving company labels for 돌아와줘.mp3 - g.o.d.
# 2025-06-27 15:35:52,793 — INFO — Processed and saved company labels for 돌아와줘.mp3 - g.o.d. 5443 songs remaining.
# 2025-06-27 15:35:53,168 — INFO — Saving company labels for 떠나지 못하는 이유.mp3 - g.o.d.
# 2025-06-27 15:35:53,170 — INFO — Processed and saved company labels for 떠나지 못하는 이유.mp3 - g.o.d. 5442 songs remaining.
# 2025-06-27 15:35:53,490 — INFO — Saving company labels for 모두 가져가 (모두 가져가).mp3 - g.o.d.
# 2025-06-27 15:35:53,491 — INFO — Processed and saved company labels for 모두 가져가 (모두 가져가).mp3 - g.o.d. 5441 songs remaining.
# 2025-06-27 15:35:53,816 — INFO — Saving company labels for 모두 가져가.mp3 - g.o.d.
# 2025-06-27 15:35:53,817 — INFO — Processed and saved company labels for 모두 가져가.mp3 - g.o.d. 5440 songs remaining.
# 2025-06-27 15:35:54,193 — INFO — Saving company labels for 모르죠.mp3 - g.o.d.
# 2025-06-27 15:35:54,195 — INFO — Processed and saved company labels for 모르죠.mp3 - g.o.d. 5439 songs remaining.
# 2025-06-27 15:35:54,543 — INFO — Saving company labels for 바보.mp3 - g.o.d.
# 2025-06-27 15:35:54,545 — INFO — Processed and saved company labels for 바보.mp3 - g.o.d. 5438 songs remaining.
# 2025-06-27 15:35:54,896 — INFO — Saving company labels for 반대가 끌리는 이유.mp3 - g.o.d.
# 2025-06-27 15:35:54,897 — INFO — Processed and saved company labels for 반대가 끌리는 이유.mp3 - g.o.d. 5437 songs remaining.
# 2025-06-27 15:35:55,198 — INFO — Saving company labels for 보통날 An Ordinary.mp3 - g.o.d.
# 2025-06-27 15:35:55,199 — INFO — Processed and saved company labels for 보통날 An Ordinary.mp3 - g.o.d. 5436 songs remaining.
# 2025-06-27 15:35:55,501 — INFO — Saving company labels for 사랑의 동그라미.mp3 - g.o.d.
# 2025-06-27 15:35:55,503 — INFO — Processed and saved company labels for 사랑의 동그라미.mp3 - g.o.d. 5435 songs remaining.
# 2025-06-27 15:35:55,660 — INFO — Saving company labels for 사랑이 너무 아프던 날.mp3 - g.o.d.
# 2025-06-27 15:35:55,662 — INFO — Processed and saved company labels for 사랑이 너무 아프던 날.mp3 - g.o.d. 5434 songs remaining.
# 2025-06-27 15:35:55,967 — INFO — Saving company labels for 사랑이 영원하다면.mp3 - g.o.d.
# 2025-06-27 15:35:55,968 — INFO — Processed and saved company labels for 사랑이 영원하다면.mp3 - g.o.d. 5433 songs remaining.
# 2025-06-27 15:35:56,072 — INFO — Saving company labels for 사랑이 전부였던 날.mp3 - g.o.d.
# 2025-06-27 15:35:56,073 — INFO — Processed and saved company labels for 사랑이 전부였던 날.mp3 - g.o.d. 5432 songs remaining.
# 2025-06-27 15:35:56,382 — INFO — Saving company labels for 사랑이 힘들 때.mp3 - g.o.d.
# 2025-06-27 15:35:56,384 — INFO — Processed and saved company labels for 사랑이 힘들 때.mp3 - g.o.d. 5431 songs remaining.
# 2025-06-27 15:35:56,702 — INFO — Saving company labels for 사랑이야기.mp3 - g.o.d.
# 2025-06-27 15:35:56,703 — INFO — Processed and saved company labels for 사랑이야기.mp3 - g.o.d. 5430 songs remaining.
# 2025-06-27 15:35:57,059 — INFO — Saving company labels for 사랑인가봐 It Might Be Love (feat. So Hyun of 3rd Coast).mp3 - g.o.d.
# 2025-06-27 15:35:57,060 — INFO — Processed and saved company labels for 사랑인가봐 It Might Be Love (feat. So Hyun of 3rd Coast).mp3 - g.o.d. 5429 songs remaining.
# 2025-06-27 15:35:57,437 — INFO — Saving company labels for 사랑해 그리고 기억해 (사랑해 그리고 기억해).mp3 - g.o.d.
# 2025-06-27 15:35:57,439 — INFO — Processed and saved company labels for 사랑해 그리고 기억해 (사랑해 그리고 기억해).mp3 - g.o.d. 5428 songs remaining.
# 2025-06-27 15:35:57,809 — INFO — Saving company labels for 사랑해 그리고 기억해.mp3 - g.o.d.
# 2025-06-27 15:35:57,811 — INFO — Processed and saved company labels for 사랑해 그리고 기억해.mp3 - g.o.d. 5427 songs remaining.
# 2025-06-27 15:35:58,091 — INFO — Saving company labels for 사랑？사랑!.mp3 - g.o.d.
# 2025-06-27 15:35:58,093 — INFO — Processed and saved company labels for 사랑？사랑!.mp3 - g.o.d. 5426 songs remaining.
# 2025-06-27 15:35:58,423 — INFO — Saving company labels for 슬픈사랑.mp3 - g.o.d.
# 2025-06-27 15:35:58,424 — INFO — Processed and saved company labels for 슬픈사랑.mp3 - g.o.d. 5425 songs remaining.
# 2025-06-27 15:35:58,832 — INFO — Saving company labels for 애수 (애수).mp3 - g.o.d.
# 2025-06-27 15:35:58,833 — INFO — Processed and saved company labels for 애수 (애수).mp3 - g.o.d. 5424 songs remaining.
# 2025-06-27 15:35:59,192 — INFO — Saving company labels for 애수.mp3 - g.o.d.
# 2025-06-27 15:35:59,194 — INFO — Processed and saved company labels for 애수.mp3 - g.o.d. 5423 songs remaining.
# 2025-06-27 15:35:59,463 — INFO — Saving company labels for 약속 (Narration 강경헌).mp3 - g.o.d.
# 2025-06-27 15:35:59,465 — INFO — Processed and saved company labels for 약속 (Narration 강경헌).mp3 - g.o.d. 5422 songs remaining.
# 2025-06-27 15:35:59,831 — INFO — Saving company labels for 어머니께 (어머니께).mp3 - g.o.d.
# 2025-06-27 15:35:59,833 — INFO — Processed and saved company labels for 어머니께 (어머니께).mp3 - g.o.d. 5421 songs remaining.
# 2025-06-27 15:36:00,164 — INFO — Saving company labels for 왜 (왜).mp3 - g.o.d.
# 2025-06-27 15:36:00,165 — INFO — Processed and saved company labels for 왜 (왜).mp3 - g.o.d. 5420 songs remaining.
# 2025-06-27 15:36:00,499 — INFO — Saving company labels for 왜.mp3 - g.o.d.
# 2025-06-27 15:36:00,501 — INFO — Processed and saved company labels for 왜.mp3 - g.o.d. 5419 songs remaining.
# 2025-06-27 15:36:00,860 — INFO — Saving company labels for 요즘.mp3 - g.o.d.
# 2025-06-27 15:36:00,862 — INFO — Processed and saved company labels for 요즘.mp3 - g.o.d. 5418 songs remaining.
# 2025-06-27 15:36:01,198 — INFO — Saving company labels for 우리.mp3 - g.o.d.
# 2025-06-27 15:36:01,199 — INFO — Processed and saved company labels for 우리.mp3 - g.o.d. 5417 songs remaining.
# 2025-06-27 15:36:01,282 — INFO — Saving company labels for 이렇게 또.mp3 - g.o.d.
# 2025-06-27 15:36:01,283 — INFO — Processed and saved company labels for 이렇게 또.mp3 - g.o.d. 5416 songs remaining.
# 2025-06-27 15:36:01,596 — INFO — Saving company labels for 익숙한 낯선 사람.mp3 - g.o.d.
# 2025-06-27 15:36:01,598 — INFO — Processed and saved company labels for 익숙한 낯선 사람.mp3 - g.o.d. 5415 songs remaining.
# 2025-06-27 15:36:01,903 — INFO — Saving company labels for 자유.mp3 - g.o.d.
# 2025-06-27 15:36:01,905 — INFO — Processed and saved company labels for 자유.mp3 - g.o.d. 5414 songs remaining.
# 2025-06-27 15:36:02,204 — INFO — Saving company labels for 작은 남자들과 함께 (작은 남자들과 함께).mp3 - g.o.d.
# 2025-06-27 15:36:02,206 — INFO — Processed and saved company labels for 작은 남자들과 함께 (작은 남자들과 함께).mp3 - g.o.d. 5413 songs remaining.
# 2025-06-27 15:36:02,484 — INFO — Saving company labels for 장미의 전쟁.mp3 - g.o.d.
# 2025-06-27 15:36:02,485 — INFO — Processed and saved company labels for 장미의 전쟁.mp3 - g.o.d. 5412 songs remaining.
# 2025-06-27 15:36:02,830 — INFO — Saving company labels for 절대 안돼.mp3 - g.o.d.
# 2025-06-27 15:36:02,831 — INFO — Processed and saved company labels for 절대 안돼.mp3 - g.o.d. 5411 songs remaining.
# 2025-06-27 15:36:03,081 — INFO — Saving company labels for 준형 MENT (준형 MENT).mp3 - g.o.d.
# 2025-06-27 15:36:03,082 — INFO — Processed and saved company labels for 준형 MENT (준형 MENT).mp3 - g.o.d. 5410 songs remaining.
# 2025-06-27 15:36:03,385 — INFO — Saving company labels for 촛불하나 (Instrumental).mp3 - g.o.d.
# 2025-06-27 15:36:03,387 — INFO — Processed and saved company labels for 촛불하나 (Instrumental).mp3 - g.o.d. 5409 songs remaining.
# 2025-06-27 15:36:03,717 — INFO — Saving company labels for 촛불하나 (촛불하나).mp3 - g.o.d.
# 2025-06-27 15:36:03,719 — INFO — Processed and saved company labels for 촛불하나 (촛불하나).mp3 - g.o.d. 5408 songs remaining.
# 2025-06-27 15:36:04,021 — INFO — Saving company labels for 촛불하나.mp3 - g.o.d.
# 2025-06-27 15:36:04,023 — INFO — Processed and saved company labels for 촛불하나.mp3 - g.o.d. 5407 songs remaining.
# 2025-06-27 15:36:04,106 — INFO — Saving company labels for 태우 MENT (태우 MENT).mp3 - g.o.d.
# 2025-06-27 15:36:04,107 — INFO — Processed and saved company labels for 태우 MENT (태우 MENT).mp3 - g.o.d. 5406 songs remaining.
# 2025-06-27 15:36:04,218 — INFO — Saving company labels for 파리 (Instrumental).mp3 - g.o.d.
# 2025-06-27 15:36:04,219 — INFO — Processed and saved company labels for 파리 (Instrumental).mp3 - g.o.d. 5405 songs remaining.
# 2025-06-27 15:36:04,594 — INFO — Saving company labels for 편지.mp3 - g.o.d.
# 2025-06-27 15:36:04,596 — INFO — Processed and saved company labels for 편지.mp3 - g.o.d. 5404 songs remaining.
# 2025-06-27 15:36:04,933 — INFO — Saving company labels for 하늘색 풍선 (하늘색 풍선).mp3 - g.o.d.
# 2025-06-27 15:36:04,935 — INFO — Processed and saved company labels for 하늘색 풍선 (하늘색 풍선).mp3 - g.o.d. 5403 songs remaining.
# 2025-06-27 15:36:05,240 — INFO — Saving company labels for 하늘색 풍선.mp3 - g.o.d.
# 2025-06-27 15:36:05,242 — INFO — Processed and saved company labels for 하늘색 풍선.mp3 - g.o.d. 5402 songs remaining.
# 2025-06-27 15:36:05,700 — INFO — Saving company labels for 한구석에.mp3 - g.o.d.
# 2025-06-27 15:36:05,702 — INFO — Processed and saved company labels for 한구석에.mp3 - g.o.d. 5401 songs remaining.
# 2025-06-27 15:36:06,065 — INFO — Saving company labels for 헤어지지 말자.mp3 - g.o.d.
# 2025-06-27 15:36:06,067 — INFO — Processed and saved company labels for 헤어지지 말자.mp3 - g.o.d. 5400 songs remaining.
# 2025-06-27 15:36:06,415 — INFO — Saving company labels for 헤어짐보다 아픈 그리움.mp3 - g.o.d.
# 2025-06-27 15:36:06,416 — INFO — Processed and saved company labels for 헤어짐보다 아픈 그리움.mp3 - g.o.d. 5399 songs remaining.
# 2025-06-27 15:36:06,489 — INFO — Saving company labels for 호영 MENT (호영 MENT).mp3 - g.o.d.
# 2025-06-27 15:36:06,491 — INFO — Processed and saved company labels for 호영 MENT (호영 MENT).mp3 - g.o.d. 5398 songs remaining.
# 2025-06-27 15:36:06,830 — INFO — Saving company labels for 143 Miles.mp3 - 2AM.
# 2025-06-27 15:36:06,831 — INFO — Processed and saved company labels for 143 Miles.mp3 - 2AM. 5397 songs remaining.
# 2025-06-27 15:36:07,140 — INFO — Saving company labels for 1second 1minute 1hour (Something Between Us X 2am) (Instrumental).mp3 - 2AM.
# 2025-06-27 15:36:07,141 — INFO — Processed and saved company labels for 1second 1minute 1hour (Something Between Us X 2am) (Instrumental).mp3 - 2AM. 5396 songs remaining.
# 2025-06-27 15:36:07,442 — INFO — Saving company labels for 1second 1minute 1hour (Something Between Us X 2am).mp3 - 2AM.
# 2025-06-27 15:36:07,444 — INFO — Processed and saved company labels for 1second 1minute 1hour (Something Between Us X 2am).mp3 - 2AM. 5395 songs remaining.
# 2025-06-27 15:36:07,748 — INFO — Saving company labels for 1초만 더 One More Second.mp3 - 2AM.
# 2025-06-27 15:36:07,750 — INFO — Processed and saved company labels for 1초만 더 One More Second.mp3 - 2AM. 5394 songs remaining.
# 2025-06-27 15:36:07,893 — INFO — Saving company labels for AGAINST THE OASIS - 3rd box studio for manipulator RJ MIX -.mp3 - 2AM.
# 2025-06-27 15:36:07,894 — INFO — Processed and saved company labels for AGAINST THE OASIS - 3rd box studio for manipulator RJ MIX -.mp3 - 2AM. 5393 songs remaining.
# 2025-06-27 15:36:08,102 — INFO — Saving company labels for Abroad.mp3 - 2AM.
# 2025-06-27 15:36:08,103 — INFO — Processed and saved company labels for Abroad.mp3 - 2AM. 5392 songs remaining.
# 2025-06-27 15:36:08,381 — INFO — Saving company labels for All Right.mp3 - 2AM.
# 2025-06-27 15:36:08,383 — INFO — Processed and saved company labels for All Right.mp3 - 2AM. 5391 songs remaining.
# 2025-06-27 15:36:08,722 — INFO — Saving company labels for Always Me.mp3 - 2AM.
# 2025-06-27 15:36:08,724 — INFO — Processed and saved company labels for Always Me.mp3 - 2AM. 5390 songs remaining.
# 2025-06-27 15:36:08,999 — INFO — Saving company labels for Battle (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:09,000 — INFO — Processed and saved company labels for Battle (feat. 小室哲哉).mp3 - 2AM. 5389 songs remaining.
# 2025-06-27 15:36:09,522 — INFO — Saving company labels for Battle - SEIZE 2005 CLUB ORBIT MIX -.mp3 - 2AM.
# 2025-06-27 15:36:09,524 — INFO — Processed and saved company labels for Battle - SEIZE 2005 CLUB ORBIT MIX -.mp3 - 2AM. 5388 songs remaining.
# 2025-06-27 15:36:09,808 — INFO — Saving company labels for Blame the Weatherman.mp3 - 2AM.
# 2025-06-27 15:36:09,809 — INFO — Processed and saved company labels for Blame the Weatherman.mp3 - 2AM. 5387 songs remaining.
# 2025-06-27 15:36:09,960 — INFO — Saving company labels for Broken Heart..mp3 - 2AM.
# 2025-06-27 15:36:09,961 — INFO — Processed and saved company labels for Broken Heart..mp3 - 2AM. 5386 songs remaining.
# 2025-06-27 15:36:10,255 — INFO — Saving company labels for Can't Say I Love You (사랑한단 말 못해).mp3 - 2AM.
# 2025-06-27 15:36:10,256 — INFO — Processed and saved company labels for Can't Say I Love You (사랑한단 말 못해).mp3 - 2AM. 5385 songs remaining.
# 2025-06-27 15:36:10,586 — INFO — Saving company labels for Cuz You Say No (아니라기에).mp3 - 2AM.
# 2025-06-27 15:36:10,587 — INFO — Processed and saved company labels for Cuz You Say No (아니라기에).mp3 - 2AM. 5384 songs remaining.
# 2025-06-27 15:36:10,885 — INFO — Saving company labels for Dance.mp3 - 2AM.
# 2025-06-27 15:36:10,887 — INFO — Processed and saved company labels for Dance.mp3 - 2AM. 5383 songs remaining.
# 2025-06-27 15:36:11,146 — INFO — Saving company labels for Down.mp3 - 2AM.
# 2025-06-27 15:36:11,149 — INFO — Processed and saved company labels for Down.mp3 - 2AM. 5382 songs remaining.
# 2025-06-27 15:36:11,302 — INFO — Saving company labels for Dreaming.mp3 - 2AM.
# 2025-06-27 15:36:11,303 — INFO — Processed and saved company labels for Dreaming.mp3 - 2AM. 5381 songs remaining.
# 2025-06-27 15:36:11,399 — INFO — Saving company labels for Epilogue (웃는다).mp3 - 2AM.
# 2025-06-27 15:36:11,401 — INFO — Processed and saved company labels for Epilogue (웃는다).mp3 - 2AM. 5380 songs remaining.
# 2025-06-27 15:36:11,612 — INFO — Saving company labels for Escapism.mp3 - 2AM.
# 2025-06-27 15:36:11,614 — INFO — Processed and saved company labels for Escapism.mp3 - 2AM. 5379 songs remaining.
# 2025-06-27 15:36:11,751 — INFO — Saving company labels for Fighting (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:11,753 — INFO — Processed and saved company labels for Fighting (feat. 小室哲哉).mp3 - 2AM. 5378 songs remaining.
# 2025-06-27 15:36:12,139 — INFO — Saving company labels for Goodlove.mp3 - 2AM.
# 2025-06-27 15:36:12,140 — INFO — Processed and saved company labels for Goodlove.mp3 - 2AM. 5377 songs remaining.
# 2025-06-27 15:36:12,607 — INFO — Saving company labels for HEADLINER SINCE 1983 - 40th ： ZXXDX & TXN RJ MIX -.mp3 - 2AM.
# 2025-06-27 15:36:12,609 — INFO — Processed and saved company labels for HEADLINER SINCE 1983 - 40th ： ZXXDX & TXN RJ MIX -.mp3 - 2AM. 5376 songs remaining.
# 2025-06-27 15:36:12,722 — INFO — Saving company labels for HOMMAGE - DNU VER.0 -.mp3 - 2AM.
# 2025-06-27 15:36:12,724 — INFO — Processed and saved company labels for HOMMAGE - DNU VER.0 -.mp3 - 2AM. 5375 songs remaining.
# 2025-06-27 15:36:13,114 — INFO — Saving company labels for I Know.mp3 - 2AM.
# 2025-06-27 15:36:13,116 — INFO — Processed and saved company labels for I Know.mp3 - 2AM. 5374 songs remaining.
# 2025-06-27 15:36:13,418 — INFO — Saving company labels for I LOVE YOU.mp3 - 2AM.
# 2025-06-27 15:36:13,420 — INFO — Processed and saved company labels for I LOVE YOU.mp3 - 2AM. 5373 songs remaining.
# 2025-06-27 15:36:13,769 — INFO — Saving company labels for I Love Emo Boyz.mp3 - 2AM.
# 2025-06-27 15:36:13,770 — INFO — Processed and saved company labels for I Love Emo Boyz.mp3 - 2AM. 5372 songs remaining.
# 2025-06-27 15:36:14,075 — INFO — Saving company labels for I Love You (Feat. 백찬, 주희 Of 8eight).mp3 - 2AM.
# 2025-06-27 15:36:14,077 — INFO — Processed and saved company labels for I Love You (Feat. 백찬, 주희 Of 8eight).mp3 - 2AM. 5371 songs remaining.
# 2025-06-27 15:36:14,420 — INFO — Saving company labels for I Was Wrong (잘못했어).mp3 - 2AM.
# 2025-06-27 15:36:14,421 — INFO — Processed and saved company labels for I Was Wrong (잘못했어).mp3 - 2AM. 5370 songs remaining.
# 2025-06-27 15:36:14,761 — INFO — Saving company labels for I can't.mp3 - 2AM.
# 2025-06-27 15:36:14,763 — INFO — Processed and saved company labels for I can't.mp3 - 2AM. 5369 songs remaining.
# 2025-06-27 15:36:15,161 — INFO — Saving company labels for I'm the One (feat. Glam) (바로 나야).mp3 - 2AM.
# 2025-06-27 15:36:15,163 — INFO — Processed and saved company labels for I'm the One (feat. Glam) (바로 나야).mp3 - 2AM. 5368 songs remaining.
# 2025-06-27 15:36:15,186 — INFO — Saving company labels for Interlude (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:15,188 — INFO — Processed and saved company labels for Interlude (feat. 小室哲哉).mp3 - 2AM. 5367 songs remaining.
# 2025-06-27 15:36:15,330 — INFO — Saving company labels for Intro - Phone.mp3 - 2AM.
# 2025-06-27 15:36:15,332 — INFO — Processed and saved company labels for Intro - Phone.mp3 - 2AM. 5366 songs remaining.
# 2025-06-27 15:36:15,423 — INFO — Saving company labels for Intro.mp3 - 2AM.
# 2025-06-27 15:36:15,425 — INFO — Processed and saved company labels for Intro.mp3 - 2AM. 5365 songs remaining.
# 2025-06-27 15:36:15,667 — INFO — Saving company labels for Like Crazy (미친 듯이).mp3 - 2AM.
# 2025-06-27 15:36:15,669 — INFO — Processed and saved company labels for Like Crazy (미친 듯이).mp3 - 2AM. 5364 songs remaining.
# 2025-06-27 15:36:15,978 — INFO — Saving company labels for Lost (Instrumental).mp3 - 2AM.
# 2025-06-27 15:36:15,980 — INFO — Processed and saved company labels for Lost (Instrumental).mp3 - 2AM. 5363 songs remaining.
# 2025-06-27 15:36:16,287 — INFO — Saving company labels for Lost.mp3 - 2AM.
# 2025-06-27 15:36:16,289 — INFO — Processed and saved company labels for Lost.mp3 - 2AM. 5362 songs remaining.
# 2025-06-27 15:36:16,719 — INFO — Saving company labels for Love (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:16,721 — INFO — Processed and saved company labels for Love (feat. 小室哲哉).mp3 - 2AM. 5361 songs remaining.
# 2025-06-27 15:36:17,054 — INFO — Saving company labels for Love Lost (Inst.) (사랑 그런거 (Inst.)).mp3 - 2AM.
# 2025-06-27 15:36:17,056 — INFO — Processed and saved company labels for Love Lost (Inst.) (사랑 그런거 (Inst.)).mp3 - 2AM. 5360 songs remaining.
# 2025-06-27 15:36:17,384 — INFO — Saving company labels for Love Lost (사랑 그런거).mp3 - 2AM.
# 2025-06-27 15:36:17,386 — INFO — Processed and saved company labels for Love Lost (사랑 그런거).mp3 - 2AM. 5359 songs remaining.
# 2025-06-27 15:36:17,668 — INFO — Saving company labels for Love U, Hate U (feat. Bangtan Boyz).mp3 - 2AM.
# 2025-06-27 15:36:17,670 — INFO — Processed and saved company labels for Love U, Hate U (feat. Bangtan Boyz).mp3 - 2AM. 5358 songs remaining.
# 2025-06-27 15:36:17,998 — INFO — Saving company labels for MOON NEVER BEG FOR ATTENTION - R COMPANY DP3 MIX -.mp3 - 2AM.
# 2025-06-27 15:36:18,000 — INFO — Processed and saved company labels for MOON NEVER BEG FOR ATTENTION - R COMPANY DP3 MIX -.mp3 - 2AM. 5357 songs remaining.
# 2025-06-27 15:36:18,216 — INFO — Saving company labels for Militant (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:18,217 — INFO — Processed and saved company labels for Militant (feat. 小室哲哉).mp3 - 2AM. 5356 songs remaining.
# 2025-06-27 15:36:18,481 — INFO — Saving company labels for Militant - LIGHTS 2005 CLUB ORBIT MIX -.mp3 - 2AM.
# 2025-06-27 15:36:18,482 — INFO — Processed and saved company labels for Militant - LIGHTS 2005 CLUB ORBIT MIX -.mp3 - 2AM. 5355 songs remaining.
# 2025-06-27 15:36:18,779 — INFO — Saving company labels for Mirage.mp3 - 2AM.
# 2025-06-27 15:36:18,780 — INFO — Processed and saved company labels for Mirage.mp3 - 2AM. 5354 songs remaining.
# 2025-06-27 15:36:19,129 — INFO — Saving company labels for Moment (Instrumental).mp3 - 2AM.
# 2025-06-27 15:36:19,133 — INFO — Processed and saved company labels for Moment (Instrumental).mp3 - 2AM. 5353 songs remaining.
# 2025-06-27 15:36:19,482 — INFO — Saving company labels for Moment.mp3 - 2AM.
# 2025-06-27 15:36:19,484 — INFO — Processed and saved company labels for Moment.mp3 - 2AM. 5352 songs remaining.
# 2025-06-27 15:36:19,831 — INFO — Saving company labels for Nervousness (불안하다).mp3 - 2AM.
# 2025-06-27 15:36:19,833 — INFO — Processed and saved company labels for Nervousness (불안하다).mp3 - 2AM. 5351 songs remaining.
# 2025-06-27 15:36:20,112 — INFO — Saving company labels for Never Let You Go (죽어도 못 보내).mp3 - 2AM.
# 2025-06-27 15:36:20,113 — INFO — Processed and saved company labels for Never Let You Go (죽어도 못 보내).mp3 - 2AM. 5350 songs remaining.
# 2025-06-27 15:36:20,229 — INFO — Saving company labels for Next... (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:20,230 — INFO — Processed and saved company labels for Next... (feat. 小室哲哉).mp3 - 2AM. 5349 songs remaining.
# 2025-06-27 15:36:20,340 — INFO — Saving company labels for Next… - EX5 SILVER 2005 ORBIT MIX -.mp3 - 2AM.
# 2025-06-27 15:36:20,342 — INFO — Processed and saved company labels for Next… - EX5 SILVER 2005 ORBIT MIX -.mp3 - 2AM. 5348 songs remaining.
# 2025-06-27 15:36:20,666 — INFO — Saving company labels for No Goodbyes (Kor Ver.).mp3 - 2AM.
# 2025-06-27 15:36:20,668 — INFO — Processed and saved company labels for No Goodbyes (Kor Ver.).mp3 - 2AM. 5347 songs remaining.
# 2025-06-27 15:36:20,981 — INFO — Saving company labels for No Goodbyes (Korean Original Ver.).mp3 - 2AM.
# 2025-06-27 15:36:20,982 — INFO — Processed and saved company labels for No Goodbyes (Korean Original Ver.).mp3 - 2AM. 5346 songs remaining.
# 2025-06-27 15:36:21,379 — INFO — Saving company labels for No Man Left Behind.mp3 - 2AM.
# 2025-06-27 15:36:21,381 — INFO — Processed and saved company labels for No Man Left Behind.mp3 - 2AM. 5345 songs remaining.
# 2025-06-27 15:36:21,682 — INFO — Saving company labels for No good in good-bye.mp3 - 2AM.
# 2025-06-27 15:36:21,683 — INFO — Processed and saved company labels for No good in good-bye.mp3 - 2AM. 5344 songs remaining.
# 2025-06-27 15:36:22,091 — INFO — Saving company labels for PRIDE OF LIFE（THE LEGEND TK MIX）.mp3 - 2AM.
# 2025-06-27 15:36:22,092 — INFO — Processed and saved company labels for PRIDE OF LIFE（THE LEGEND TK MIX）.mp3 - 2AM. 5343 songs remaining.
# 2025-06-27 15:36:22,328 — INFO — Saving company labels for Prologue.mp3 - 2AM.
# 2025-06-27 15:36:22,330 — INFO — Processed and saved company labels for Prologue.mp3 - 2AM. 5342 songs remaining.
# 2025-06-27 15:36:22,713 — INFO — Saving company labels for Propose (청혼).mp3 - 2AM.
# 2025-06-27 15:36:22,715 — INFO — Processed and saved company labels for Propose (청혼).mp3 - 2AM. 5341 songs remaining.
# 2025-06-27 15:36:22,997 — INFO — Saving company labels for Propose.mp3 - 2AM.
# 2025-06-27 15:36:22,999 — INFO — Processed and saved company labels for Propose.mp3 - 2AM. 5340 songs remaining.
# 2025-06-27 15:36:23,124 — INFO — Saving company labels for Running Smoothly (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:23,126 — INFO — Processed and saved company labels for Running Smoothly (feat. 小室哲哉).mp3 - 2AM. 5339 songs remaining.
# 2025-06-27 15:36:23,447 — INFO — Saving company labels for Should′ve known.mp3 - 2AM.
# 2025-06-27 15:36:23,449 — INFO — Processed and saved company labels for Should′ve known.mp3 - 2AM. 5338 songs remaining.
# 2025-06-27 15:36:23,541 — INFO — Saving company labels for Siren's Trick (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:23,543 — INFO — Processed and saved company labels for Siren's Trick (feat. 小室哲哉).mp3 - 2AM. 5337 songs remaining.
# 2025-06-27 15:36:23,647 — INFO — Saving company labels for Spring.mp3 - 2AM.
# 2025-06-27 15:36:23,648 — INFO — Processed and saved company labels for Spring.mp3 - 2AM. 5336 songs remaining.
# 2025-06-27 15:36:24,001 — INFO — Saving company labels for Summer Love (Freestyle Radio).mp3 - 2AM.
# 2025-06-27 15:36:24,002 — INFO — Processed and saved company labels for Summer Love (Freestyle Radio).mp3 - 2AM. 5335 songs remaining.
# 2025-06-27 15:36:24,319 — INFO — Saving company labels for Sunshine.mp3 - 2AM.
# 2025-06-27 15:36:24,321 — INFO — Processed and saved company labels for Sunshine.mp3 - 2AM. 5334 songs remaining.
# 2025-06-27 15:36:24,435 — INFO — Saving company labels for TEARS IN HEAVEN - 3rd box studio for manipulator RJ MIX -.mp3 - 2AM.
# 2025-06-27 15:36:24,436 — INFO — Processed and saved company labels for TEARS IN HEAVEN - 3rd box studio for manipulator RJ MIX -.mp3 - 2AM. 5333 songs remaining.
# 2025-06-27 15:36:24,561 — INFO — Saving company labels for THE PROUD - CRITICISM 8MEN AND ROXY VERSION -.mp3 - 2AM.
# 2025-06-27 15:36:24,563 — INFO — Processed and saved company labels for THE PROUD - CRITICISM 8MEN AND ROXY VERSION -.mp3 - 2AM. 5332 songs remaining.
# 2025-06-27 15:36:24,964 — INFO — Saving company labels for The New One.mp3 - 2AM.
# 2025-06-27 15:36:24,966 — INFO — Processed and saved company labels for The New One.mp3 - 2AM. 5331 songs remaining.
# 2025-06-27 15:36:25,326 — INFO — Saving company labels for There Is Nothing More (이젠 없다).mp3 - 2AM.
# 2025-06-27 15:36:25,328 — INFO — Processed and saved company labels for There Is Nothing More (이젠 없다).mp3 - 2AM. 5330 songs remaining.
# 2025-06-27 15:36:25,681 — INFO — Saving company labels for Though You're Gone (Instrumental).mp3 - 2AM.
# 2025-06-27 15:36:25,682 — INFO — Processed and saved company labels for Though You're Gone (Instrumental).mp3 - 2AM. 5329 songs remaining.
# 2025-06-27 15:36:26,011 — INFO — Saving company labels for Though You're Gone.mp3 - 2AM.
# 2025-06-27 15:36:26,013 — INFO — Processed and saved company labels for Though You're Gone.mp3 - 2AM. 5328 songs remaining.
# 2025-06-27 15:36:26,326 — INFO — Saving company labels for To Love You Again (다시 사랑하기엔).mp3 - 2AM.
# 2025-06-27 15:36:26,327 — INFO — Processed and saved company labels for To Love You Again (다시 사랑하기엔).mp3 - 2AM. 5327 songs remaining.
# 2025-06-27 15:36:26,413 — INFO — Saving company labels for To. AM (For you).mp3 - 2AM.
# 2025-06-27 15:36:26,415 — INFO — Processed and saved company labels for To. AM (For you).mp3 - 2AM. 5326 songs remaining.
# 2025-06-27 15:36:26,617 — INFO — Saving company labels for We Could Have Been Something but,.mp3 - 2AM.
# 2025-06-27 15:36:26,619 — INFO — Processed and saved company labels for We Could Have Been Something but,.mp3 - 2AM. 5325 songs remaining.
# 2025-06-27 15:36:26,941 — INFO — Saving company labels for What Should I Do (어떡하죠).mp3 - 2AM.
# 2025-06-27 15:36:26,942 — INFO — Processed and saved company labels for What Should I Do (어떡하죠).mp3 - 2AM. 5324 songs remaining.
# 2025-06-27 15:36:27,279 — INFO — Saving company labels for With or Without U.mp3 - 2AM.
# 2025-06-27 15:36:27,281 — INFO — Processed and saved company labels for With or Without U.mp3 - 2AM. 5323 songs remaining.
# 2025-06-27 15:36:27,612 — INFO — Saving company labels for Without you (Inst.).mp3 - 2AM.
# 2025-06-27 15:36:27,614 — INFO — Processed and saved company labels for Without you (Inst.).mp3 - 2AM. 5322 songs remaining.
# 2025-06-27 15:36:27,951 — INFO — Saving company labels for Without you.mp3 - 2AM.
# 2025-06-27 15:36:27,952 — INFO — Processed and saved company labels for Without you.mp3 - 2AM. 5321 songs remaining.
# 2025-06-27 15:36:28,282 — INFO — Saving company labels for You Wouldn't Answer My Calls (전활 받지 않는 너에게).mp3 - 2AM.
# 2025-06-27 15:36:28,283 — INFO — Processed and saved company labels for You Wouldn't Answer My Calls (전활 받지 않는 너에게).mp3 - 2AM. 5320 songs remaining.
# 2025-06-27 15:36:28,419 — INFO — Saving company labels for Zoids Drive (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:28,420 — INFO — Processed and saved company labels for Zoids Drive (feat. 小室哲哉).mp3 - 2AM. 5319 songs remaining.
# 2025-06-27 15:36:28,728 — INFO — Saving company labels for loveskin.mp3 - 2AM.
# 2025-06-27 15:36:28,730 — INFO — Processed and saved company labels for loveskin.mp3 - 2AM. 5318 songs remaining.
# 2025-06-27 15:36:28,854 — INFO — Saving company labels for 不気味な勢力 (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:28,856 — INFO — Processed and saved company labels for 不気味な勢力 (feat. 小室哲哉).mp3 - 2AM. 5317 songs remaining.
# 2025-06-27 15:36:29,168 — INFO — Saving company labels for 光る眼 (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:29,169 — INFO — Processed and saved company labels for 光る眼 (feat. 小室哲哉).mp3 - 2AM. 5316 songs remaining.
# 2025-06-27 15:36:29,534 — INFO — Saving company labels for 光る眼 - THE SINGLE CUT 2025 FROM 2amJAPAN OSTCD -.mp3 - 2AM.
# 2025-06-27 15:36:29,535 — INFO — Processed and saved company labels for 光る眼 - THE SINGLE CUT 2025 FROM 2amJAPAN OSTCD -.mp3 - 2AM. 5315 songs remaining.
# 2025-06-27 15:36:29,637 — INFO — Saving company labels for 出動！ (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:29,639 — INFO — Processed and saved company labels for 出動！ (feat. 小室哲哉).mp3 - 2AM. 5314 songs remaining.
# 2025-06-27 15:36:29,815 — INFO — Saving company labels for 失墜の時 (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:29,817 — INFO — Processed and saved company labels for 失墜の時 (feat. 小室哲哉).mp3 - 2AM. 5313 songs remaining.
# 2025-06-27 15:36:29,892 — INFO — Saving company labels for 巨大要塞 (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:29,893 — INFO — Processed and saved company labels for 巨大要塞 (feat. 小室哲哉).mp3 - 2AM. 5312 songs remaining.
# 2025-06-27 15:36:29,977 — INFO — Saving company labels for 強敵 (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:29,978 — INFO — Processed and saved company labels for 強敵 (feat. 小室哲哉).mp3 - 2AM. 5311 songs remaining.
# 2025-06-27 15:36:30,206 — INFO — Saving company labels for 涙 (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:30,208 — INFO — Processed and saved company labels for 涙 (feat. 小室哲哉).mp3 - 2AM. 5310 songs remaining.
# 2025-06-27 15:36:30,344 — INFO — Saving company labels for 牙の逆襲 (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:30,346 — INFO — Processed and saved company labels for 牙の逆襲 (feat. 小室哲哉).mp3 - 2AM. 5309 songs remaining.
# 2025-06-27 15:36:30,510 — INFO — Saving company labels for 疾走の牙 (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:30,512 — INFO — Processed and saved company labels for 疾走の牙 (feat. 小室哲哉).mp3 - 2AM. 5308 songs remaining.
# 2025-06-27 15:36:30,602 — INFO — Saving company labels for 立ち塞がる壁 (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:30,604 — INFO — Processed and saved company labels for 立ち塞がる壁 (feat. 小室哲哉).mp3 - 2AM. 5307 songs remaining.
# 2025-06-27 15:36:30,693 — INFO — Saving company labels for 紅く妖艶な企み (feat. 小室哲哉).mp3 - 2AM.
# 2025-06-27 15:36:30,694 — INFO — Processed and saved company labels for 紅く妖艶な企み (feat. 小室哲哉).mp3 - 2AM. 5306 songs remaining.
# 2025-06-27 15:36:30,820 — INFO — Saving company labels for 良く晴れた日 (feat. 小室哲哉).mp3 - 2AM.
# ...
# 2025-06-27 16:04:57,077 — INFO — Saving company labels for ORANGE (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure.
# 2025-06-27 16:04:57,081 — INFO — Processed and saved company labels for ORANGE (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 65 songs remaining.
# 2025-06-27 16:04:57,400 — INFO — Saving company labels for REVERSE (2024 TREASURE FAN MEETING~WONDERLAND~).mp3 - Treasure.
# 2025-06-27 16:04:57,404 — INFO — Processed and saved company labels for REVERSE (2024 TREASURE FAN MEETING~WONDERLAND~).mp3 - Treasure. 64 songs remaining.
# 2025-06-27 16:04:57,521 — INFO — Saving company labels for REVERSE - Drama Edit -.mp3 - Treasure.
# 2025-06-27 16:04:57,526 — INFO — Processed and saved company labels for REVERSE - Drama Edit -.mp3 - Treasure. 63 songs remaining.
# 2025-06-27 16:04:57,854 — INFO — Saving company labels for REVERSE.mp3 - Treasure.
# 2025-06-27 16:04:57,858 — INFO — Processed and saved company labels for REVERSE.mp3 - Treasure. 62 songs remaining.
# 2025-06-27 16:04:58,095 — INFO — Saving company labels for RHYTHM TA REMIX (Rock Ver.) (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure.
# 2025-06-27 16:04:58,100 — INFO — Processed and saved company labels for RHYTHM TA REMIX (Rock Ver.) (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 61 songs remaining.
# 2025-06-27 16:04:58,421 — INFO — Saving company labels for RUN (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure.
# 2025-06-27 16:04:58,425 — INFO — Processed and saved company labels for RUN (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 60 songs remaining.
# 2025-06-27 16:04:58,722 — INFO — Saving company labels for RUN.mp3 - Treasure.
# 2025-06-27 16:04:58,726 — INFO — Processed and saved company labels for RUN.mp3 - Treasure. 59 songs remaining.
# 2025-06-27 16:04:58,981 — INFO — Saving company labels for SARURU.mp3 - Treasure.
# 2025-06-27 16:04:58,985 — INFO — Processed and saved company labels for SARURU.mp3 - Treasure. 58 songs remaining.
# 2025-06-27 16:04:59,239 — INFO — Saving company labels for SLOWMOTION (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure.
# 2025-06-27 16:04:59,243 — INFO — Processed and saved company labels for SLOWMOTION (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 57 songs remaining.
# 2025-06-27 16:04:59,503 — INFO — Saving company labels for SLOWMOTION.mp3 - Treasure.
# 2025-06-27 16:04:59,507 — INFO — Processed and saved company labels for SLOWMOTION.mp3 - Treasure. 56 songs remaining.
# 2025-06-27 16:04:59,772 — INFO — Saving company labels for STUPID (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure.
# 2025-06-27 16:04:59,776 — INFO — Processed and saved company labels for STUPID (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 55 songs remaining.
# 2025-06-27 16:05:00,030 — INFO — Saving company labels for STUPID -JP Ver.-.mp3 - Treasure.
# 2025-06-27 16:05:00,033 — INFO — Processed and saved company labels for STUPID -JP Ver.-.mp3 - Treasure. 54 songs remaining.
# 2025-06-27 16:05:00,319 — INFO — Saving company labels for THANK YOU (ASAHI x HARUTO Unit).mp3 - Treasure.
# 2025-06-27 16:05:00,323 — INFO — Processed and saved company labels for THANK YOU (ASAHI x HARUTO Unit).mp3 - Treasure. 53 songs remaining.
# 2025-06-27 16:05:00,654 — INFO — Saving company labels for THE WAY TO (JIHOON × JUNKYU × PARK JEONG WOO Unit) (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure.
# 2025-06-27 16:05:00,658 — INFO — Processed and saved company labels for THE WAY TO (JIHOON × JUNKYU × PARK JEONG WOO Unit) (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 52 songs remaining.
# 2025-06-27 16:05:00,893 — INFO — Saving company labels for U (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure.
# 2025-06-27 16:05:00,897 — INFO — Processed and saved company labels for U (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 51 songs remaining.
# 2025-06-27 16:05:01,133 — INFO — Saving company labels for U.mp3 - Treasure.
# 2025-06-27 16:05:01,137 — INFO — Processed and saved company labels for U.mp3 - Treasure. 50 songs remaining.
# 2025-06-27 16:05:01,239 — INFO — Saving company labels for VolKno (CHOI HYUN SUK x YOSHI x HARUTO Unit) (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure.
# 2025-06-27 16:05:01,243 — INFO — Processed and saved company labels for VolKno (CHOI HYUN SUK x YOSHI x HARUTO Unit) (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 49 songs remaining.
# 2025-06-27 16:05:01,515 — INFO — Saving company labels for VolKno (CHOI HYUN SUK x YOSHI x HARUTO Unit) (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in....mp3 - Treasure.
# 2025-06-27 16:05:01,518 — INFO — Processed and saved company labels for VolKno (CHOI HYUN SUK x YOSHI x HARUTO Unit) (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in....mp3 - Treasure. 48 songs remaining.
# 2025-06-27 16:05:01,797 — INFO — Saving company labels for VolKno (CHOI HYUN SUK x YOSHI x HARUTO Unit) -JP Ver.-.mp3 - Treasure.
# 2025-06-27 16:05:01,801 — INFO — Processed and saved company labels for VolKno (CHOI HYUN SUK x YOSHI x HARUTO Unit) -JP Ver.-.mp3 - Treasure. 47 songs remaining.
# 2025-06-27 16:05:02,080 — INFO — Saving company labels for VolKno (CHOI HYUN SUK x YOSHI x HARUTO Unit).mp3 - Treasure.
# 2025-06-27 16:05:02,084 — INFO — Processed and saved company labels for VolKno (CHOI HYUN SUK x YOSHI x HARUTO Unit).mp3 - Treasure. 46 songs remaining.
# 2025-06-27 16:05:02,410 — INFO — Saving company labels for WHATEVER, WHENEVER.mp3 - Treasure.
# 2025-06-27 16:05:02,413 — INFO — Processed and saved company labels for WHATEVER, WHENEVER.mp3 - Treasure. 45 songs remaining.
# 2025-06-27 16:05:02,668 — INFO — Saving company labels for WONDERLAND (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure.
# 2025-06-27 16:05:02,672 — INFO — Processed and saved company labels for WONDERLAND (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 44 songs remaining.
# 2025-06-27 16:05:02,928 — INFO — Saving company labels for WONDERLAND.mp3 - Treasure.
# 2025-06-27 16:05:02,931 — INFO — Processed and saved company labels for WONDERLAND.mp3 - Treasure. 43 songs remaining.
# 2025-06-27 16:05:03,198 — INFO — Saving company labels for YELLOW -JP Ver.-.mp3 - Treasure.
# 2025-06-27 16:05:03,202 — INFO — Processed and saved company labels for YELLOW -JP Ver.-.mp3 - Treasure. 42 songs remaining.
# 2025-06-27 16:05:03,462 — INFO — Saving company labels for YELLOW.mp3 - Treasure.
# 2025-06-27 16:05:03,465 — INFO — Processed and saved company labels for YELLOW.mp3 - Treasure. 41 songs remaining.
# 2025-06-27 16:05:03,819 — INFO — Saving company labels for ありがとう (ASAHI x HARUTO Unit) (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure.
# 2025-06-27 16:05:03,823 — INFO — Processed and saved company labels for ありがとう (ASAHI x HARUTO Unit) (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 40 songs remaining.
# 2025-06-27 16:05:04,126 — INFO — Saving company labels for ありがとう (ASAHI x HARUTO Unit) (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA....mp3 - Treasure.
# 2025-06-27 16:05:04,130 — INFO — Processed and saved company labels for ありがとう (ASAHI x HARUTO Unit) (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA....mp3 - Treasure. 39 songs remaining.
# 2025-06-27 16:05:04,408 — INFO — Saving company labels for ありがとう (ASAHI x HARUTO Unit) -JP Ver.-.mp3 - Treasure.
# 2025-06-27 16:05:04,412 — INFO — Processed and saved company labels for ありがとう (ASAHI x HARUTO Unit) -JP Ver.-.mp3 - Treasure. 38 songs remaining.
# 2025-06-27 16:05:04,823 — INFO — Saving company labels for オレンジ (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure.
# 2025-06-27 16:05:04,827 — INFO — Processed and saved company labels for オレンジ (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 37 songs remaining.
# 2025-06-27 16:05:05,206 — INFO — Saving company labels for オレンジ.mp3 - Treasure.
# 2025-06-27 16:05:05,210 — INFO — Processed and saved company labels for オレンジ.mp3 - Treasure. 36 songs remaining.
# 2025-06-27 16:05:05,540 — INFO — Saving company labels for ミチョガネ.mp3 - Treasure.
# 2025-06-27 16:05:05,544 — INFO — Processed and saved company labels for ミチョガネ.mp3 - Treasure. 35 songs remaining.
# 2025-06-27 16:05:05,830 — INFO — Saving company labels for 病 (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure.
# 2025-06-27 16:05:05,833 — INFO — Processed and saved company labels for 病 (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 34 songs remaining.
# 2025-06-27 16:05:06,145 — INFO — Saving company labels for 病 (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure.
# 2025-06-27 16:05:06,149 — INFO — Processed and saved company labels for 病 (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 33 songs remaining.
# 2025-06-27 16:05:06,445 — INFO — Saving company labels for 病.mp3 - Treasure.
# 2025-06-27 16:05:06,449 — INFO — Processed and saved company labels for 病.mp3 - Treasure. 32 songs remaining.
# 2025-06-27 16:05:06,766 — INFO — Saving company labels for 괜찮아질 거야 (IT’S OKAY).mp3 - Treasure.
# 2025-06-27 16:05:06,769 — INFO — Processed and saved company labels for 괜찮아질 거야 (IT’S OKAY).mp3 - Treasure. 31 songs remaining.
# 2025-06-27 16:05:07,026 — INFO — Saving company labels for 나랑 있자 (BE WITH ME).mp3 - Treasure.
# 2025-06-27 16:05:07,030 — INFO — Processed and saved company labels for 나랑 있자 (BE WITH ME).mp3 - Treasure. 30 songs remaining.
# 2025-06-27 16:05:07,354 — INFO — Saving company labels for 다라리 (DARARI).mp3 - Treasure.
# 2025-06-27 16:05:07,358 — INFO — Processed and saved company labels for 다라리 (DARARI).mp3 - Treasure. 29 songs remaining.
# 2025-06-27 16:05:07,659 — INFO — Saving company labels for 들어와 (Come To Me).mp3 - Treasure.
# 2025-06-27 16:05:07,664 — INFO — Processed and saved company labels for 들어와 (Come To Me).mp3 - Treasure. 28 songs remaining.
# 2025-06-27 16:05:07,920 — INFO — Saving company labels for 멍청이 (STUPID).mp3 - Treasure.
# 2025-06-27 16:05:07,924 — INFO — Processed and saved company labels for 멍청이 (STUPID).mp3 - Treasure. 27 songs remaining.
# 2025-06-27 16:05:08,272 — INFO — Saving company labels for 미쳐가네 (Going Crazy).mp3 - Treasure.
# 2025-06-27 16:05:08,276 — INFO — Processed and saved company labels for 미쳐가네 (Going Crazy).mp3 - Treasure. 26 songs remaining.
# 2025-06-27 16:05:08,567 — INFO — Saving company labels for 병 (LOVESICK).mp3 - Treasure.
# 2025-06-27 16:05:08,571 — INFO — Processed and saved company labels for 병 (LOVESICK).mp3 - Treasure. 25 songs remaining.
# 2025-06-27 16:05:08,833 — INFO — Saving company labels for 사랑해 (I Love You).mp3 - Treasure.
# 2025-06-27 16:05:08,837 — INFO — Processed and saved company labels for 사랑해 (I Love You).mp3 - Treasure. 24 songs remaining.
# 2025-06-27 16:05:09,128 — INFO — Saving company labels for 어른 (THE WAY TO) (VOCAL Unit).mp3 - Treasure.
# 2025-06-27 16:05:09,132 — INFO — Processed and saved company labels for 어른 (THE WAY TO) (VOCAL Unit).mp3 - Treasure. 23 songs remaining.
# 2025-06-27 16:05:09,511 — INFO — Saving company labels for 오렌지 (Orange).mp3 - Treasure.
# 2025-06-27 16:05:09,515 — INFO — Processed and saved company labels for 오렌지 (Orange).mp3 - Treasure. 22 songs remaining.
# 2025-06-27 16:05:09,822 — INFO — Saving company labels for 음 (MMM).mp3 - Treasure.
# 2025-06-27 16:05:09,826 — INFO — Processed and saved company labels for 음 (MMM).mp3 - Treasure. 21 songs remaining.
# 2025-06-27 16:05:10,085 — INFO — Saving company labels for 직진 (JIKJIN).mp3 - Treasure.
# 2025-06-27 16:05:10,089 — INFO — Processed and saved company labels for 직진 (JIKJIN).mp3 - Treasure. 20 songs remaining.
# 2025-06-27 16:05:10,371 — INFO — Saving company labels for BATTER UP (7 ver.).mp3 - BabyMonster.
# 2025-06-27 16:05:10,375 — INFO — Processed and saved company labels for BATTER UP (7 ver.).mp3 - BabyMonster. 19 songs remaining.
# 2025-06-27 16:05:10,699 — INFO — Saving company labels for BATTER UP (Remix) - Bonus Track.mp3 - BabyMonster.
# 2025-06-27 16:05:10,703 — INFO — Processed and saved company labels for BATTER UP (Remix) - Bonus Track.mp3 - BabyMonster. 18 songs remaining.
# 2025-06-27 16:05:10,965 — INFO — Saving company labels for BATTER UP -JP Version.mp3 - BabyMonster.
# 2025-06-27 16:05:10,969 — INFO — Processed and saved company labels for BATTER UP -JP Version.mp3 - BabyMonster. 17 songs remaining.
# 2025-06-27 16:05:11,236 — INFO — Saving company labels for BATTER UP.mp3 - BabyMonster.
# 2025-06-27 16:05:11,240 — INFO — Processed and saved company labels for BATTER UP.mp3 - BabyMonster. 16 songs remaining.
# 2025-06-27 16:05:11,459 — INFO — Saving company labels for BILLIONAIRE.mp3 - BabyMonster.
# 2025-06-27 16:05:11,463 — INFO — Processed and saved company labels for BILLIONAIRE.mp3 - BabyMonster. 15 songs remaining.
# 2025-06-27 16:05:11,695 — INFO — Saving company labels for CLIK CLAK.mp3 - BabyMonster.
# 2025-06-27 16:05:11,698 — INFO — Processed and saved company labels for CLIK CLAK.mp3 - BabyMonster. 14 songs remaining.
# 2025-06-27 16:05:11,948 — INFO — Saving company labels for DREAM.mp3 - BabyMonster.
# 2025-06-27 16:05:11,952 — INFO — Processed and saved company labels for DREAM.mp3 - BabyMonster. 13 songs remaining.
# 2025-06-27 16:05:12,210 — INFO — Saving company labels for DRIP.mp3 - BabyMonster.
# 2025-06-27 16:05:12,214 — INFO — Processed and saved company labels for DRIP.mp3 - BabyMonster. 12 songs remaining.
# 2025-06-27 16:05:12,574 — INFO — Saving company labels for FOREVER.mp3 - BabyMonster.
# 2025-06-27 16:05:12,579 — INFO — Processed and saved company labels for FOREVER.mp3 - BabyMonster. 11 songs remaining.
# 2025-06-27 16:05:12,833 — INFO — Saving company labels for Ghost.mp3 - BabyMonster.
# 2025-06-27 16:05:12,837 — INFO — Processed and saved company labels for Ghost.mp3 - BabyMonster. 10 songs remaining.
# 2025-06-27 16:05:13,080 — INFO — Saving company labels for LIKE THAT.mp3 - BabyMonster.
# 2025-06-27 16:05:13,085 — INFO — Processed and saved company labels for LIKE THAT.mp3 - BabyMonster. 9 songs remaining.
# 2025-06-27 16:05:13,357 — INFO — Saving company labels for Love In My Heart.mp3 - BabyMonster.
# 2025-06-27 16:05:13,362 — INFO — Processed and saved company labels for Love In My Heart.mp3 - BabyMonster. 8 songs remaining.
# 2025-06-27 16:05:13,614 — INFO — Saving company labels for Love, Maybe.mp3 - BabyMonster.
# 2025-06-27 16:05:13,619 — INFO — Processed and saved company labels for Love, Maybe.mp3 - BabyMonster. 7 songs remaining.
# 2025-06-27 16:05:13,681 — INFO — Saving company labels for MONSTERS (Intro).mp3 - BabyMonster.
# 2025-06-27 16:05:13,685 — INFO — Processed and saved company labels for MONSTERS (Intro).mp3 - BabyMonster. 6 songs remaining.
# 2025-06-27 16:05:13,959 — INFO — Saving company labels for Really Like You.mp3 - BabyMonster.
# 2025-06-27 16:05:13,963 — INFO — Processed and saved company labels for Really Like You.mp3 - BabyMonster. 5 songs remaining.
# 2025-06-27 16:05:14,207 — INFO — Saving company labels for SHEESH.mp3 - BabyMonster.
# 2025-06-27 16:05:14,211 — INFO — Processed and saved company labels for SHEESH.mp3 - BabyMonster. 4 songs remaining.
# 2025-06-27 16:05:14,629 — INFO — Saving company labels for Stuck In The Middle (7 ver.).mp3 - BabyMonster.
# 2025-06-27 16:05:14,633 — INFO — Processed and saved company labels for Stuck In The Middle (7 ver.).mp3 - BabyMonster. 3 songs remaining.
# 2025-06-27 16:05:14,911 — INFO — Saving company labels for Stuck In The Middle (Remix).mp3 - BabyMonster.
# 2025-06-27 16:05:14,915 — INFO — Processed and saved company labels for Stuck In The Middle (Remix).mp3 - BabyMonster. 2 songs remaining.
# 2025-06-27 16:05:15,259 — INFO — Saving company labels for Stuck In The Middle.mp3 - BabyMonster.
# 2025-06-27 16:05:15,263 — INFO — Processed and saved company labels for Stuck In The Middle.mp3 - BabyMonster. 1 songs remaining.
# 2025-06-27 16:05:15,471 — INFO — Saving company labels for Woke Up In Tokyo (RUKA & ASA).mp3 - BabyMonster.
# 2025-06-27 16:05:15,475 — INFO — Processed and saved company labels for Woke Up In Tokyo (RUKA & ASA).mp3 - BabyMonster. 0 songs remaining.
