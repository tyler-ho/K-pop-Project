# %%
# %load_ext cuml.accel
# %load_ext cudf.pandas
# Out:
# cuML: Accelerator installed.

# %%
import rmm
rmm.reinitialize(
    pool_allocator=True,
    initial_pool_size=20<<30,   # 20 GiB pool (tweak as you like)
    managed_memory=False
)
rmm.mr.set_current_device_resource(rmm.mr.ManagedMemoryResource())

# %%
import numpy as np
import pandas as pd
import sklearn as sk
import seaborn as sns
import matplotlib.pyplot as plt
import unicodedata
import warnings
import pickle
import logging
import librosa
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# Now that we have our imports, we want to import the data. This will be seen as de-pickling the Songs.pkl file, import to a DataFrame, and then accessing each song.

# %%
# load df
Songs = []
with open("Songs.pkl", 'rb') as f:
    Songs = pickle.load(f) 
data = [vars(song) for song in Songs]
df = pd.DataFrame(data)
df
# Out:
# 2025-06-26 15:21:19,902 — INFO — init
#                                                    path company generation  \
# 0     /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...     JYP          1
# 1     /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...     JYP          1
# 2     /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...     JYP          1
# 3     /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...     JYP          1
# 4     /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...     JYP          1
# ...                                                 ...     ...        ...
# 5522  /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...      YG          5
# 5523  /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...      YG          5
# 5524  /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...      YG          5
# 5525  /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...      YG          5
# 5526  /home/tyler/gdrive/K-pop Project 2024-5/K-pop ...      YG          5
#
#            artist                               name features
# 0           g.o.d                             0%.mp3     <NA>
# 1           g.o.d                         134-14.mp3     <NA>
# 2           g.o.d                             20.mp3     <NA>
# 3           g.o.d                     21C 우리의 희망.mp3     <NA>
# 4           g.o.d                     5+4+1+5=15.mp3     <NA>
# ...           ...                                ...      ...
# 5522  BabyMonster                         SHEESH.mp3     <NA>
# 5523  BabyMonster   Stuck In The Middle (7 ver.).mp3     <NA>
# 5524  BabyMonster    Stuck In The Middle (Remix).mp3     <NA>
# 5525  BabyMonster            Stuck In The Middle.mp3     <NA>
# 5526  BabyMonster  Woke Up In Tokyo (RUKA & ASA).mp3     <NA>
#
# [5527 rows x 6 columns]

# %%
# need some logging to make skip work already done and to find failures
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s — %(levelname)s — %(message)s",
    handlers=[
        logging.FileHandler("/home/tyler/Downloads/kpop_project/logs/new_process_librosa.log"),
        logging.StreamHandler()
    ]
)

# %%
def process_librosa(audio, sr):
    # Extract MFCC features using librosa
    mfccs = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=13)
    mfccs_mean = np.mean(mfccs.T, axis=0)  # Get mean of MFCC features

    # Chroma features
    chroma = librosa.feature.chroma_stft(y=audio, sr=sr)
    chroma_mean = np.mean(chroma.T, axis=0)

    # Spectral Contrast
    spectral_contrast = librosa.feature.spectral_contrast(y=audio, sr=sr)
    spectral_contrast_mean = np.mean(spectral_contrast.T, axis=0)

    # Zero-Crossing Rate
    zcr = librosa.feature.zero_crossing_rate(y=audio)
    zcr_mean = np.mean(zcr.T, axis=0)

    # Root Mean Square Energy
    rmse = librosa.feature.rms(y=audio)
    rmse_mean = np.mean(rmse.T, axis=0)

    # Spectral Centroid
    spectral_centroid = librosa.feature.spectral_centroid(y=audio, sr=sr)
    spectral_centroid_mean = np.mean(spectral_centroid.T, axis=0)

    # Spectral Bandwidth
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=audio, sr=sr)
    spectral_bandwidth_mean = np.mean(spectral_bandwidth.T, axis=0)

    # Spectral Flatness
    spectral_flatness = librosa.feature.spectral_flatness(y=audio)
    spectral_flatness_mean = np.mean(spectral_flatness.T, axis=0)

    # Tonnetz
    tonnetz = librosa.feature.tonnetz(y=audio, sr=sr)
    tonnetz_mean = np.mean(tonnetz.T, axis=0)

    # Combine features into a single feature vector
    features = np.concatenate((
        mfccs_mean, chroma_mean, spectral_contrast_mean,
        zcr_mean, rmse_mean, spectral_centroid_mean,
        spectral_bandwidth_mean, spectral_flatness_mean,
        tonnetz_mean
    ))
    return features

# %%
# split songs into clips
clip_duration = 30
overlap = 10
x_out = "/home/tyler/gdrive/K-pop Project 2024-5/K-pop Project/ML_inputs/features.pkl" 
X = pickle.load(open(x_out, 'rb'))
# X = []
labels_out = "/home/tyler/gdrive/K-pop Project 2024-5/K-pop Project/ML_inputs/labels.pkl"
labels = pickle.load(open(labels_out, 'rb'))
# labels = []
seen_out = "/home/tyler/gdrive/K-pop Project 2024-5/K-pop Project/ML_inputs/seen.pkl"
seen = pickle.load(open(seen_out, 'rb'))
# seen = set()
completed = 0
for row in df.itertuples():
    if row.path in seen:
        logging.info(f"Skipping {row.name} - {row.artist}, already processed.")
        completed += 1
    else:
        # creates 30-second clips of audio with 10 seconds of audio; removes clips that are less than 30 seconds at the end (loses at most 9 seconds at the end)
        y, sr = librosa.load(unicodedata.normalize('NFC', row.path))
        clip_length = clip_duration * sr
        hop_length = int(clip_length *(1 - (float(overlap) / clip_duration)))
        end_spot = int(len(y) - clip_length + 1)
        for start_sample in range(0, end_spot, hop_length):
            clip = y[start_sample:start_sample + clip_length]
            features = process_librosa(clip, sr)
            # Append features and corresponding label
            X.append(features)  # Append to list
            labels.append(int(row.generation))
        seen.add(row.path)
        # keyboard interrupts will only occur before serializing processed data or after, never in the middle 
        try:
            pickle.dump(X, open(x_out, 'wb'))
            pickle.dump(labels, open(labels_out, 'wb'))
            pickle.dump(seen, open(seen_out, 'wb'))
            completed += 1
            logging.info(f"Processed and saved features for {row.name} - {row.artist}. {df.shape[0] - completed} songs remaining.")
        except KeyboardInterrupt:
            # Ignore Ctrl+C during vital section
            print("KeyboardInterrupt ignored in vital section")
# Out:
# 2025-06-26 16:22:58,447 — INFO — Skipping 0%.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,447 — INFO — Skipping 134-14.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,448 — INFO — Skipping 20.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,449 — INFO — Skipping 21C 우리의 희망.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,449 — INFO — Skipping 5+4+1+5=15.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,450 — INFO — Skipping 5집을 내며.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,450 — INFO — Skipping A Funny But Sad Day (웃픈 하루) (Inst.).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,450 — INFO — Skipping A Funny But Sad Day (웃픈 하루).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,451 — INFO — Skipping An Ordinary Day (보통날) (Original Ver.).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,452 — INFO — Skipping Confession (Instrumental) (지금 만나러 갈게 (Inst.)).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,452 — INFO — Skipping Confession (지금 만나러 갈게).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,453 — INFO — Skipping Dance All Night.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,454 — INFO — Skipping Dance all night (Dance all night).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,454 — INFO — Skipping Exit, 20The Century-Enter The 21St.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,454 — INFO — Skipping Eye To Eye (눈을 맞춰).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,455 — INFO — Skipping Five Men and a Kiddo (아저씨와 메건리).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,455 — INFO — Skipping Friday Night.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,456 — INFO — Skipping Friday night (Friday night).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,456 — INFO — Skipping G'swag (신사의 품격).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,457 — INFO — Skipping God 파티.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,457 — INFO — Skipping I Know (나는 알아) (Prod. Joon Park) (박준형).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,458 — INFO — Skipping I Like It (난 좋아).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,459 — INFO — Skipping Intro.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,459 — INFO — Skipping Leave Him (그 남자를 떠나).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,459 — INFO — Skipping Loving You.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,460 — INFO — Skipping MENT 1 (MENT 1).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,460 — INFO — Skipping MENT 2 (MENT 2).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,461 — INFO — Skipping Not Knowing (모르죠) (Prod. Son Ho Young) (손호영).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,461 — INFO — Skipping OPENING MENT (OPENING MENT).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,462 — INFO — Skipping Report To The Dance Floor.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,463 — INFO — Skipping Road (길) (song by IU) (아이유) , Henry (헨리) , Jo Hyunah (조현아) , Yang Da Il....mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,463 — INFO — Skipping Saturday Night (Inst.).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,464 — INFO — Skipping Saturday Night.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,464 — INFO — Skipping Say God.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,465 — INFO — Skipping Say god (Say god).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,465 — INFO — Skipping Sing for Me (노래 불러줘요) (feat. IU) (아이유).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,466 — INFO — Skipping Sky Blue Promise (하늘색 약속).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,466 — INFO — Skipping Smile.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,467 — INFO — Skipping Snowfall (눈이 내린다) (inst.).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,467 — INFO — Skipping Snowfall (눈이 내린다).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,468 — INFO — Skipping So You Can Come Back to Me (니가 다시 돌아올 수 있도록) (Prod. Yoon Kye Sang)....mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,469 — INFO — Skipping Stand Up.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,469 — INFO — Skipping The Lone Duckling (미운오리새끼) (Inst.).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,470 — INFO — Skipping The Lone Duckling (미운오리새끼).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,471 — INFO — Skipping The Story of Our Lives (우리가 사는 이야기) (Inst.).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,471 — INFO — Skipping The Story of Our Lives (우리가 사는 이야기) (feat. Megan Lee) (메건리).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,471 — INFO — Skipping The Things You Need to Do (네가 할 일) (Inst.).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,472 — INFO — Skipping The Things You Need to Do (네가 할 일).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,472 — INFO — Skipping Tonight.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,473 — INFO — Skipping Where you Belong (니가 있어야 할 곳) (Prod. Kim Tae Woo) (김태우).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,473 — INFO — Skipping Why (왜) (Prod. Danny Ahn) (데니안).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,474 — INFO — Skipping Wind (바람) (Inst.).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,474 — INFO — Skipping Wind (바람).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,475 — INFO — Skipping champion title song (champion title song).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,475 — INFO — Skipping 가자.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,476 — INFO — Skipping 거짓말 (거짓말).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,476 — INFO — Skipping 거짓말.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,477 — INFO — Skipping 걸어선 안되는 전화.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,478 — INFO — Skipping 계상 MENT (계상 MENT).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,478 — INFO — Skipping 관찰 (관찰).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,479 — INFO — Skipping 그대 날 떠난 후로 (그대 날 떠난 후로).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,479 — INFO — Skipping 그대 날 떠난 후로.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,480 — INFO — Skipping 기차.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,481 — INFO — Skipping 기회를 줘.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,481 — INFO — Skipping 길 (Instrumental).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,482 — INFO — Skipping 길.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,482 — INFO — Skipping 꿈이었으면 If It Were a Dream (feat. Sweet Sorrow).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,483 — INFO — Skipping 나는 알아.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,484 — INFO — Skipping 나와 함께 춤을 춰.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,485 — INFO — Skipping 난 남자가 있어 (With김정은).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,485 — INFO — Skipping 난 사랑을 몰라 (난 사랑을 몰라).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,485 — INFO — Skipping 난 사랑을 몰라.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,486 — INFO — Skipping 날 기다려줘 (날 기다려줘).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,487 — INFO — Skipping 눈치 없는 눈물.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,487 — INFO — Skipping 니가 다시 돌아올수 있도록 (니가 다시 돌아올수 있도록).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,488 — INFO — Skipping 니가 있어야 할 곳.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,488 — INFO — Skipping 니가 필요해 (니가 필요해).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,489 — INFO — Skipping 니가 필요해.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,490 — INFO — Skipping 다섯 남자 이야기.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,490 — INFO — Skipping 다시.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,491 — INFO — Skipping 더듬고 있어.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,491 — INFO — Skipping 데니 MENT (데니 MENT).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,492 — INFO — Skipping 돌아와줘 (돌아와줘).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,492 — INFO — Skipping 돌아와줘.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,493 — INFO — Skipping 떠나지 못하는 이유.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,494 — INFO — Skipping 모두 가져가 (모두 가져가).mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,494 — INFO — Skipping 모두 가져가.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,495 — INFO — Skipping 모르죠.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,495 — INFO — Skipping 바보.mp3 - g.o.d, already processed.
# 2025-06-26 16:22:58,496 — INFO — Skipping 반대가 끌리는 이유.mp3 - g.o.d, already processed.
# 2025-06-26 16:23:09,869 — INFO — Processed and saved features for 보통날 An Ordinary.mp3 - g.o.d. 5436 songs remaining.
# 2025-06-26 16:23:21,786 — INFO — Processed and saved features for 사랑의 동그라미.mp3 - g.o.d. 5435 songs remaining.
# 2025-06-26 16:23:32,141 — INFO — Processed and saved features for 사랑이 너무 아프던 날.mp3 - g.o.d. 5434 songs remaining.
# 2025-06-26 16:23:46,226 — INFO — Processed and saved features for 사랑이 영원하다면.mp3 - g.o.d. 5433 songs remaining.
# 2025-06-26 16:23:55,177 — INFO — Processed and saved features for 사랑이 전부였던 날.mp3 - g.o.d. 5432 songs remaining.
# 2025-06-26 16:24:07,419 — INFO — Processed and saved features for 사랑이 힘들 때.mp3 - g.o.d. 5431 songs remaining.
# 2025-06-26 16:24:19,764 — INFO — Processed and saved features for 사랑이야기.mp3 - g.o.d. 5430 songs remaining.
# 2025-06-26 16:24:33,581 — INFO — Processed and saved features for 사랑인가봐 It Might Be Love (feat. So Hyun of 3rd Coast).mp3 - g.o.d. 5429 songs remaining.
# 2025-06-26 16:24:48,167 — INFO — Processed and saved features for 사랑해 그리고 기억해 (사랑해 그리고 기억해).mp3 - g.o.d. 5428 songs remaining.
# 2025-06-26 16:25:00,640 — INFO — Processed and saved features for 사랑해 그리고 기억해.mp3 - g.o.d. 5427 songs remaining.
# 2025-06-26 16:25:11,287 — INFO — Processed and saved features for 사랑？사랑!.mp3 - g.o.d. 5426 songs remaining.
# 2025-06-26 16:25:24,007 — INFO — Processed and saved features for 슬픈사랑.mp3 - g.o.d. 5425 songs remaining.
# 2025-06-26 16:25:40,565 — INFO — Processed and saved features for 애수 (애수).mp3 - g.o.d. 5424 songs remaining.
# 2025-06-26 16:25:52,488 — INFO — Processed and saved features for 애수.mp3 - g.o.d. 5423 songs remaining.
# 2025-06-26 16:26:03,606 — INFO — Processed and saved features for 약속 (Narration 강경헌).mp3 - g.o.d. 5422 songs remaining.
# 2025-06-26 16:26:17,112 — INFO — Processed and saved features for 어머니께 (어머니께).mp3 - g.o.d. 5421 songs remaining.
# 2025-06-26 16:26:31,822 — INFO — Processed and saved features for 왜 (왜).mp3 - g.o.d. 5420 songs remaining.
# 2025-06-26 16:26:46,444 — INFO — Processed and saved features for 왜.mp3 - g.o.d. 5419 songs remaining.
# 2025-06-26 16:26:57,826 — INFO — Processed and saved features for 요즘.mp3 - g.o.d. 5418 songs remaining.
# 2025-06-26 16:27:10,977 — INFO — Processed and saved features for 우리.mp3 - g.o.d. 5417 songs remaining.
# 2025-06-26 16:27:19,458 — INFO — Processed and saved features for 이렇게 또.mp3 - g.o.d. 5416 songs remaining.
# 2025-06-26 16:27:31,631 — INFO — Processed and saved features for 익숙한 낯선 사람.mp3 - g.o.d. 5415 songs remaining.
# 2025-06-26 16:27:42,833 — INFO — Processed and saved features for 자유.mp3 - g.o.d. 5414 songs remaining.
# 2025-06-26 16:27:53,686 — INFO — Processed and saved features for 작은 남자들과 함께 (작은 남자들과 함께).mp3 - g.o.d. 5413 songs remaining.
# 2025-06-26 16:28:08,830 — INFO — Processed and saved features for 장미의 전쟁.mp3 - g.o.d. 5412 songs remaining.
# 2025-06-26 16:28:21,663 — INFO — Processed and saved features for 절대 안돼.mp3 - g.o.d. 5411 songs remaining.
# 2025-06-26 16:28:33,330 — INFO — Processed and saved features for 준형 MENT (준형 MENT).mp3 - g.o.d. 5410 songs remaining.
# 2025-06-26 16:28:44,282 — INFO — Processed and saved features for 촛불하나 (Instrumental).mp3 - g.o.d. 5409 songs remaining.
# 2025-06-26 16:28:58,831 — INFO — Processed and saved features for 촛불하나 (촛불하나).mp3 - g.o.d. 5408 songs remaining.
# 2025-06-26 16:29:12,672 — INFO — Processed and saved features for 촛불하나.mp3 - g.o.d. 5407 songs remaining.
# 2025-06-26 16:29:21,131 — INFO — Processed and saved features for 태우 MENT (태우 MENT).mp3 - g.o.d. 5406 songs remaining.
# 2025-06-26 16:29:30,770 — INFO — Processed and saved features for 파리 (Instrumental).mp3 - g.o.d. 5405 songs remaining.
# 2025-06-26 16:29:43,817 — INFO — Processed and saved features for 편지.mp3 - g.o.d. 5404 songs remaining.
# 2025-06-26 16:29:56,085 — INFO — Processed and saved features for 하늘색 풍선 (하늘색 풍선).mp3 - g.o.d. 5403 songs remaining.
# 2025-06-26 16:30:07,049 — INFO — Processed and saved features for 하늘색 풍선.mp3 - g.o.d. 5402 songs remaining.
# 2025-06-26 16:30:20,841 — INFO — Processed and saved features for 한구석에.mp3 - g.o.d. 5401 songs remaining.
# 2025-06-26 16:30:32,300 — INFO — Processed and saved features for 헤어지지 말자.mp3 - g.o.d. 5400 songs remaining.
# 2025-06-26 16:30:46,602 — INFO — Processed and saved features for 헤어짐보다 아픈 그리움.mp3 - g.o.d. 5399 songs remaining.
# 2025-06-26 16:30:55,322 — INFO — Processed and saved features for 호영 MENT (호영 MENT).mp3 - g.o.d. 5398 songs remaining.
# 2025-06-26 16:31:07,786 — INFO — Processed and saved features for 143 Miles.mp3 - 2AM. 5397 songs remaining.
# 2025-06-26 16:31:19,741 — INFO — Processed and saved features for 1second 1minute 1hour (Something Between Us X 2am) (Instrumental).mp3 - 2AM. 5396 songs remaining.
# 2025-06-26 16:31:30,858 — INFO — Processed and saved features for 1second 1minute 1hour (Something Between Us X 2am).mp3 - 2AM. 5395 songs remaining.
# 2025-06-26 16:31:41,911 — INFO — Processed and saved features for 1초만 더 One More Second.mp3 - 2AM. 5394 songs remaining.
# 2025-06-26 16:31:54,540 — INFO — Processed and saved features for AGAINST THE OASIS - 3rd box studio for manipulator RJ MIX -.mp3 - 2AM. 5393 songs remaining.
# 2025-06-26 16:32:03,546 — INFO — Processed and saved features for Abroad.mp3 - 2AM. 5392 songs remaining.
# 2025-06-26 16:32:15,260 — INFO — Processed and saved features for All Right.mp3 - 2AM. 5391 songs remaining.
# 2025-06-26 16:32:26,622 — INFO — Processed and saved features for Always Me.mp3 - 2AM. 5390 songs remaining.
# 2025-06-26 16:32:36,882 — INFO — Processed and saved features for Battle (feat. 小室哲哉).mp3 - 2AM. 5389 songs remaining.
# 2025-06-26 16:32:52,823 — INFO — Processed and saved features for Battle - SEIZE 2005 CLUB ORBIT MIX -.mp3 - 2AM. 5388 songs remaining.
# 2025-06-26 16:33:08,672 — INFO — Processed and saved features for Blame the Weatherman.mp3 - 2AM. 5387 songs remaining.
# 2025-06-26 16:33:16,829 — INFO — Processed and saved features for Broken Heart..mp3 - 2AM. 5386 songs remaining.
# 2025-06-26 16:33:27,865 — INFO — Processed and saved features for Can't Say I Love You (사랑한단 말 못해).mp3 - 2AM. 5385 songs remaining.
# 2025-06-26 16:33:39,390 — INFO — Processed and saved features for Cuz You Say No (아니라기에).mp3 - 2AM. 5384 songs remaining.
# 2025-06-26 16:33:50,550 — INFO — Processed and saved features for Dance.mp3 - 2AM. 5383 songs remaining.
# 2025-06-26 16:34:02,481 — INFO — Processed and saved features for Down.mp3 - 2AM. 5382 songs remaining.
# 2025-06-26 16:34:11,252 — INFO — Processed and saved features for Dreaming.mp3 - 2AM. 5381 songs remaining.
# 2025-06-26 16:34:19,673 — INFO — Processed and saved features for Epilogue (웃는다).mp3 - 2AM. 5380 songs remaining.
# 2025-06-26 16:34:30,628 — INFO — Processed and saved features for Escapism.mp3 - 2AM. 5379 songs remaining.
# 2025-06-26 16:34:40,985 — INFO — Processed and saved features for Fighting (feat. 小室哲哉).mp3 - 2AM. 5378 songs remaining.
# 2025-06-26 16:34:53,749 — INFO — Processed and saved features for Goodlove.mp3 - 2AM. 5377 songs remaining.
# 2025-06-26 16:35:07,764 — INFO — Processed and saved features for HEADLINER SINCE 1983 - 40th ： ZXXDX & TXN RJ MIX -.mp3 - 2AM. 5376 songs remaining.
# 2025-06-26 16:35:17,240 — INFO — Processed and saved features for HOMMAGE - DNU VER.0 -.mp3 - 2AM. 5375 songs remaining.
# 2025-06-26 16:35:31,211 — INFO — Processed and saved features for I Know.mp3 - 2AM. 5374 songs remaining.
# 2025-06-26 16:35:44,721 — INFO — Processed and saved features for I LOVE YOU.mp3 - 2AM. 5373 songs remaining.
# 2025-06-26 16:36:00,606 — INFO — Processed and saved features for I Love Emo Boyz.mp3 - 2AM. 5372 songs remaining.
# 2025-06-26 16:36:14,480 — INFO — Processed and saved features for I Love You (Feat. 백찬, 주희 Of 8eight).mp3 - 2AM. 5371 songs remaining.
# 2025-06-26 16:36:26,187 — INFO — Processed and saved features for I Was Wrong (잘못했어).mp3 - 2AM. 5370 songs remaining.
# 2025-06-26 16:36:40,093 — INFO — Processed and saved features for I can't.mp3 - 2AM. 5369 songs remaining.
# 2025-06-26 16:36:52,184 — INFO — Processed and saved features for I'm the One (feat. Glam) (바로 나야).mp3 - 2AM. 5368 songs remaining.
# 2025-06-26 16:37:04,491 — INFO — Processed and saved features for Interlude (feat. 小室哲哉).mp3 - 2AM. 5367 songs remaining.
# 2025-06-26 16:37:15,460 — INFO — Processed and saved features for Intro - Phone.mp3 - 2AM. 5366 songs remaining.
# 2025-06-26 16:37:25,516 — INFO — Processed and saved features for Intro.mp3 - 2AM. 5365 songs remaining.
# 2025-06-26 16:37:37,679 — INFO — Processed and saved features for Like Crazy (미친 듯이).mp3 - 2AM. 5364 songs remaining.
# 2025-06-26 16:37:48,521 — INFO — Processed and saved features for Lost (Instrumental).mp3 - 2AM. 5363 songs remaining.
# 2025-06-26 16:38:07,101 — INFO — Processed and saved features for Lost.mp3 - 2AM. 5362 songs remaining.
# 2025-06-26 16:38:21,536 — INFO — Processed and saved features for Love (feat. 小室哲哉).mp3 - 2AM. 5361 songs remaining.
# 2025-06-26 16:38:33,092 — INFO — Processed and saved features for Love Lost (Inst.) (사랑 그런거 (Inst.)).mp3 - 2AM. 5360 songs remaining.
# 2025-06-26 16:38:45,766 — INFO — Processed and saved features for Love Lost (사랑 그런거).mp3 - 2AM. 5359 songs remaining.
# 2025-06-26 16:38:57,316 — INFO — Processed and saved features for Love U, Hate U (feat. Bangtan Boyz).mp3 - 2AM. 5358 songs remaining.
# 2025-06-26 16:39:08,845 — INFO — Processed and saved features for MOON NEVER BEG FOR ATTENTION - R COMPANY DP3 MIX -.mp3 - 2AM. 5357 songs remaining.
# 2025-06-26 16:39:19,762 — INFO — Processed and saved features for Militant (feat. 小室哲哉).mp3 - 2AM. 5356 songs remaining.
# 2025-06-26 16:39:32,123 — INFO — Processed and saved features for Militant - LIGHTS 2005 CLUB ORBIT MIX -.mp3 - 2AM. 5355 songs remaining.
# 2025-06-26 16:39:44,238 — INFO — Processed and saved features for Mirage.mp3 - 2AM. 5354 songs remaining.
# 2025-06-26 16:39:59,688 — INFO — Processed and saved features for Moment (Instrumental).mp3 - 2AM. 5353 songs remaining.
# 2025-06-26 16:40:12,209 — INFO — Processed and saved features for Moment.mp3 - 2AM. 5352 songs remaining.
# 2025-06-26 16:40:25,391 — INFO — Processed and saved features for Nervousness (불안하다).mp3 - 2AM. 5351 songs remaining.
# 2025-06-26 16:40:36,562 — INFO — Processed and saved features for Never Let You Go (죽어도 못 보내).mp3 - 2AM. 5350 songs remaining.
# 2025-06-26 16:40:46,927 — INFO — Processed and saved features for Next... (feat. 小室哲哉).mp3 - 2AM. 5349 songs remaining.
# 2025-06-26 16:40:56,880 — INFO — Processed and saved features for Next… - EX5 SILVER 2005 ORBIT MIX -.mp3 - 2AM. 5348 songs remaining.
# 2025-06-26 16:41:08,475 — INFO — Processed and saved features for No Goodbyes (Kor Ver.).mp3 - 2AM. 5347 songs remaining.
# 2025-06-26 16:41:22,770 — INFO — Processed and saved features for No Goodbyes (Korean Original Ver.).mp3 - 2AM. 5346 songs remaining.
# 2025-06-26 16:41:34,615 — INFO — Processed and saved features for No Man Left Behind.mp3 - 2AM. 5345 songs remaining.
# 2025-06-26 16:41:45,931 — INFO — Processed and saved features for No good in good-bye.mp3 - 2AM. 5344 songs remaining.
# 2025-06-26 16:41:57,423 — INFO — Processed and saved features for PRIDE OF LIFE（THE LEGEND TK MIX）.mp3 - 2AM. 5343 songs remaining.
# 2025-06-26 16:42:10,651 — INFO — Processed and saved features for Prologue.mp3 - 2AM. 5342 songs remaining.
# 2025-06-26 16:42:23,759 — INFO — Processed and saved features for Propose (청혼).mp3 - 2AM. 5341 songs remaining.
# 2025-06-26 16:42:33,769 — INFO — Processed and saved features for Propose.mp3 - 2AM. 5340 songs remaining.
# 2025-06-26 16:42:43,405 — INFO — Processed and saved features for Running Smoothly (feat. 小室哲哉).mp3 - 2AM. 5339 songs remaining.
# 2025-06-26 16:42:54,949 — INFO — Processed and saved features for Should′ve known.mp3 - 2AM. 5338 songs remaining.
# 2025-06-26 16:43:07,879 — INFO — Processed and saved features for Siren's Trick (feat. 小室哲哉).mp3 - 2AM. 5337 songs remaining.
# 2025-06-26 16:43:16,279 — INFO — Processed and saved features for Spring.mp3 - 2AM. 5336 songs remaining.
# 2025-06-26 16:43:29,352 — INFO — Processed and saved features for Summer Love (Freestyle Radio).mp3 - 2AM. 5335 songs remaining.
# 2025-06-26 16:43:42,729 — INFO — Processed and saved features for Sunshine.mp3 - 2AM. 5334 songs remaining.
# 2025-06-26 16:43:52,160 — INFO — Processed and saved features for TEARS IN HEAVEN - 3rd box studio for manipulator RJ MIX -.mp3 - 2AM. 5333 songs remaining.
# 2025-06-26 16:44:00,715 — INFO — Processed and saved features for THE PROUD - CRITICISM 8MEN AND ROXY VERSION -.mp3 - 2AM. 5332 songs remaining.
# 2025-06-26 16:44:13,115 — INFO — Processed and saved features for The New One.mp3 - 2AM. 5331 songs remaining.
# 2025-06-26 16:44:24,623 — INFO — Processed and saved features for There Is Nothing More (이젠 없다).mp3 - 2AM. 5330 songs remaining.
# 2025-06-26 16:44:36,489 — INFO — Processed and saved features for Though You're Gone (Instrumental).mp3 - 2AM. 5329 songs remaining.
# 2025-06-26 16:44:50,841 — INFO — Processed and saved features for Though You're Gone.mp3 - 2AM. 5328 songs remaining.
# 2025-06-26 16:45:02,025 — INFO — Processed and saved features for To Love You Again (다시 사랑하기엔).mp3 - 2AM. 5327 songs remaining.
# 2025-06-26 16:45:10,257 — INFO — Processed and saved features for To. AM (For you).mp3 - 2AM. 5326 songs remaining.
# 2025-06-26 16:45:20,174 — INFO — Processed and saved features for We Could Have Been Something but,.mp3 - 2AM. 5325 songs remaining.
# 2025-06-26 16:45:32,821 — INFO — Processed and saved features for What Should I Do (어떡하죠).mp3 - 2AM. 5324 songs remaining.
# 2025-06-26 16:45:45,188 — INFO — Processed and saved features for With or Without U.mp3 - 2AM. 5323 songs remaining.
# 2025-06-26 16:45:57,252 — INFO — Processed and saved features for Without you (Inst.).mp3 - 2AM. 5322 songs remaining.
# 2025-06-26 16:46:08,221 — INFO — Processed and saved features for Without you.mp3 - 2AM. 5321 songs remaining.
# 2025-06-26 16:46:19,550 — INFO — Processed and saved features for You Wouldn't Answer My Calls (전활 받지 않는 너에게).mp3 - 2AM. 5320 songs remaining.
# 2025-06-26 16:46:29,930 — INFO — Processed and saved features for Zoids Drive (feat. 小室哲哉).mp3 - 2AM. 5319 songs remaining.
# 2025-06-26 16:46:41,572 — INFO — Processed and saved features for loveskin.mp3 - 2AM. 5318 songs remaining.
# 2025-06-26 16:46:51,053 — INFO — Processed and saved features for 不気味な勢力 (feat. 小室哲哉).mp3 - 2AM. 5317 songs remaining.
# 2025-06-26 16:47:01,287 — INFO — Processed and saved features for 光る眼 (feat. 小室哲哉).mp3 - 2AM. 5316 songs remaining.
# 2025-06-26 16:47:13,502 — INFO — Processed and saved features for 光る眼 - THE SINGLE CUT 2025 FROM 2amJAPAN OSTCD -.mp3 - 2AM. 5315 songs remaining.
# 2025-06-26 16:47:22,578 — INFO — Processed and saved features for 出動！ (feat. 小室哲哉).mp3 - 2AM. 5314 songs remaining.
# 2025-06-26 16:47:33,335 — INFO — Processed and saved features for 失墜の時 (feat. 小室哲哉).mp3 - 2AM. 5313 songs remaining.
# 2025-06-26 16:47:41,733 — INFO — Processed and saved features for 巨大要塞 (feat. 小室哲哉).mp3 - 2AM. 5312 songs remaining.
# 2025-06-26 16:47:50,321 — INFO — Processed and saved features for 強敵 (feat. 小室哲哉).mp3 - 2AM. 5311 songs remaining.
# 2025-06-26 16:48:03,616 — INFO — Processed and saved features for 涙 (feat. 小室哲哉).mp3 - 2AM. 5310 songs remaining.
# 2025-06-26 16:48:11,881 — INFO — Processed and saved features for 牙の逆襲 (feat. 小室哲哉).mp3 - 2AM. 5309 songs remaining.
# 2025-06-26 16:48:23,126 — INFO — Processed and saved features for 疾走の牙 (feat. 小室哲哉).mp3 - 2AM. 5308 songs remaining.
# 2025-06-26 16:48:31,180 — INFO — Processed and saved features for 立ち塞がる壁 (feat. 小室哲哉).mp3 - 2AM. 5307 songs remaining.
# 2025-06-26 16:48:40,772 — INFO — Processed and saved features for 紅く妖艶な企み (feat. 小室哲哉).mp3 - 2AM. 5306 songs remaining.
# 2025-06-26 16:48:51,374 — INFO — Processed and saved features for 良く晴れた日 (feat. 小室哲哉).mp3 - 2AM. 5305 songs remaining.
# 2025-06-26 16:49:01,982 — INFO — Processed and saved features for 逆転 (feat. 小室哲哉).mp3 - 2AM. 5304 songs remaining.
# 2025-06-26 16:49:10,251 — INFO — Processed and saved features for 風切る強敵 (feat. 小室哲哉).mp3 - 2AM. 5303 songs remaining.
# 2025-06-26 16:49:19,479 — INFO — Processed and saved features for 驚異的な戦闘力 (feat. 小室哲哉).mp3 - 2AM. 5302 songs remaining.
# 2025-06-26 16:49:32,518 — INFO — Processed and saved features for 驚異的な戦闘力 - THE SINGLE CUT 2025 FROM 2amJAPAN OSTCD -.mp3 - 2AM. 5301 songs remaining.
# 2025-06-26 16:49:43,719 — INFO — Processed and saved features for 鮮やかな恐怖 (feat. 小室哲哉).mp3 - 2AM. 5300 songs remaining.
# 2025-06-26 16:49:53,552 — INFO — Processed and saved features for 黒い霧 (feat. 小室哲哉).mp3 - 2AM. 5299 songs remaining.
# 2025-06-26 16:50:05,225 — INFO — Processed and saved features for 그냥 있어줘.mp3 - 2AM. 5298 songs remaining.
# 2025-06-26 16:50:18,769 — INFO — Processed and saved features for 그녀에게 (Feat. 찬성 Of 2PM).mp3 - 2AM. 5297 songs remaining.
# 2025-06-26 16:50:31,195 — INFO — Processed and saved features for 그녀에게.mp3 - 2AM. 5296 songs remaining.
# 2025-06-26 16:50:43,149 — INFO — Processed and saved features for 그대 잊고.mp3 - 2AM. 5295 songs remaining.
# 2025-06-26 16:50:54,973 — INFO — Processed and saved features for 그때.mp3 - 2AM. 5294 songs remaining.
# 2025-06-26 16:51:08,621 — INFO — Processed and saved features for 나타나 주라 Over the Destiny.mp3 - 2AM. 5293 songs remaining.
# 2025-06-26 16:51:21,083 — INFO — Processed and saved features for 내 사랑은 말야 Love Actually.mp3 - 2AM. 5292 songs remaining.
# 2025-06-26 16:51:33,949 — INFO — Processed and saved features for 내 생각 Think of Me.mp3 - 2AM. 5291 songs remaining.
# 2025-06-26 16:51:46,096 — INFO — Processed and saved features for 내게 온다.mp3 - 2AM. 5290 songs remaining.
# 2025-06-26 16:51:58,257 — INFO — Processed and saved features for 내꺼였는데 You Were Mine.mp3 - 2AM. 5289 songs remaining.
# 2025-06-26 16:52:10,044 — INFO — Processed and saved features for 너도 나처럼 I Wonder If You Hurt Like Me.mp3 - 2AM. 5288 songs remaining.
# 2025-06-26 16:52:25,114 — INFO — Processed and saved features for 너를 읽어보다.mp3 - 2AM. 5287 songs remaining.
# 2025-06-26 16:52:37,234 — INFO — Processed and saved features for 너뿐이야.mp3 - 2AM. 5286 songs remaining.
# 2025-06-26 16:52:48,654 — INFO — Processed and saved features for 볼수록 예뻐.mp3 - 2AM. 5285 songs remaining.
# 2025-06-26 16:53:02,668 — INFO — Processed and saved features for 사랑해 사랑해 I Love You, I Love You.mp3 - 2AM. 5284 songs remaining.
# 2025-06-26 16:53:13,580 — INFO — Processed and saved features for 실감 Realized.mp3 - 2AM. 5283 songs remaining.
# 2025-06-26 16:53:25,617 — INFO — Processed and saved features for 아니라기에 (Instrumental).mp3 - 2AM. 5282 songs remaining.
# 2025-06-26 16:53:38,324 — INFO — Processed and saved features for 아니라기에 Cuz You Say No.mp3 - 2AM. 5281 songs remaining.
# 2025-06-26 16:53:50,559 — INFO — Processed and saved features for 아니라기에.mp3 - 2AM. 5280 songs remaining.
# 2025-06-26 16:54:04,732 — INFO — Processed and saved features for 어느 봄날 One Spring Day (Inst.).mp3 - 2AM. 5279 songs remaining.
# 2025-06-26 16:54:15,726 — INFO — Processed and saved features for 어느 봄날 One Spring Day.mp3 - 2AM. 5278 songs remaining.
# 2025-06-26 16:54:29,079 — INFO — Processed and saved features for 어떡하죠 What Should I Do.mp3 - 2AM. 5277 songs remaining.
# 2025-06-26 16:54:41,107 — INFO — Processed and saved features for 어떡하죠.mp3 - 2AM. 5276 songs remaining.
# 2025-06-26 16:54:54,188 — INFO — Processed and saved features for 오늘따라 days like today.mp3 - 2AM. 5275 songs remaining.
# 2025-06-26 16:55:04,380 — INFO — Processed and saved features for 웃는다 (Outro).mp3 - 2AM. 5274 songs remaining.
# 2025-06-26 16:55:19,983 — INFO — Processed and saved features for 웃어 줄 수 없어서 미안하다.mp3 - 2AM. 5273 songs remaining.
# 2025-06-26 16:55:32,383 — INFO — Processed and saved features for 위로.mp3 - 2AM. 5272 songs remaining.
# 2025-06-26 16:55:45,784 — INFO — Processed and saved features for 이노래 (Instrumental).mp3 - 2AM. 5271 songs remaining.
# 2025-06-26 16:55:59,471 — INFO — Processed and saved features for 이노래.mp3 - 2AM. 5270 songs remaining.
# 2025-06-26 16:56:12,840 — INFO — Processed and saved features for 이별 그 날 The Day.mp3 - 2AM. 5269 songs remaining.
# 2025-06-26 16:56:25,623 — INFO — Processed and saved features for 일단 돌아서지만 For Now, I'll Walk Away (Instrumental).mp3 - 2AM. 5268 songs remaining.
# 2025-06-26 16:56:37,634 — INFO — Processed and saved features for 일단 돌아서지만 For Now, I'll Walk Away.mp3 - 2AM. 5267 songs remaining.
# 2025-06-26 16:56:49,471 — INFO — Processed and saved features for 일단 돌아서지만.mp3 - 2AM. 5266 songs remaining.
# 2025-06-26 16:57:01,382 — INFO — Processed and saved features for 잘 이별하기 How to Break Up Well.mp3 - 2AM. 5265 songs remaining.
# 2025-06-26 16:57:14,357 — INFO — Processed and saved features for 잘못했어 I Was Wrong.mp3 - 2AM. 5264 songs remaining.
# 2025-06-26 16:57:29,031 — INFO — Processed and saved features for 죽어도 못 보내 Never Let You Go.mp3 - 2AM. 5263 songs remaining.
# 2025-06-26 16:57:42,517 — INFO — Processed and saved features for 준비 Ready.mp3 - 2AM. 5262 songs remaining.
# 2025-06-26 16:58:00,237 — INFO — Processed and saved features for 찜했어 Be My Lady.mp3 - 2AM. 5261 songs remaining.
# 2025-06-26 16:58:11,989 — INFO — Processed and saved features for 천사에게.mp3 - 2AM. 5260 songs remaining.
# 2025-06-26 16:58:24,013 — INFO — Processed and saved features for 추억 다 지워 Erase All Our Memories.mp3 - 2AM. 5259 songs remaining.
# 2025-06-26 16:58:38,483 — INFO — Processed and saved features for 친구의 고백 Confession of a Friend (Instrumental).mp3 - 2AM. 5258 songs remaining.
# 2025-06-26 16:58:51,785 — INFO — Processed and saved features for 친구의 고백 Confession of a Friend.mp3 - 2AM. 5257 songs remaining.
# 2025-06-26 16:59:04,405 — INFO — Processed and saved features for 해피엔드 Happy End.mp3 - 2AM. 5256 songs remaining.
# 2025-06-26 16:59:15,374 — INFO — Processed and saved features for 후회할거야.mp3 - 2AM. 5255 songs remaining.
# 2025-06-26 16:59:28,417 — INFO — Processed and saved features for 10 Out of 10.mp3 - 2PM. 5254 songs remaining.
# 2025-06-26 16:59:40,787 — INFO — Processed and saved features for 365 (Instrumental).mp3 - 2PM. 5253 songs remaining.
# 2025-06-26 16:59:52,596 — INFO — Processed and saved features for 365.mp3 - 2PM. 5252 songs remaining.
# 2025-06-26 17:00:05,795 — INFO — Processed and saved features for Again & Again.mp3 - 2PM. 5251 songs remaining.
# 2025-06-26 17:00:18,650 — INFO — Processed and saved features for Beat of Love.mp3 - 2PM. 5250 songs remaining.
# 2025-06-26 17:00:34,396 — INFO — Processed and saved features for Beautiful ((Without Main Vocal) [Instrumental]).mp3 - 2PM. 5249 songs remaining.
# 2025-06-26 17:00:46,559 — INFO — Processed and saved features for Beautiful (Aqua Blu Mix).mp3 - 2PM. 5248 songs remaining.
# 2025-06-26 17:00:59,160 — INFO — Processed and saved features for Beautiful Day.mp3 - 2PM. 5247 songs remaining.
# 2025-06-26 17:01:13,436 — INFO — Processed and saved features for Beautiful.mp3 - 2PM. 5246 songs remaining.
# 2025-06-26 17:01:28,704 — INFO — Processed and saved features for Breakthrough.mp3 - 2PM. 5245 songs remaining.
# 2025-06-26 17:01:41,261 — INFO — Processed and saved features for Burning Love.mp3 - 2PM. 5244 songs remaining.
# 2025-06-26 17:01:57,459 — INFO — Processed and saved features for By My Side.mp3 - 2PM. 5243 songs remaining.
# 2025-06-26 17:02:09,885 — INFO — Processed and saved features for Chikai No Christmas.mp3 - 2PM. 5242 songs remaining.
# 2025-06-26 17:02:21,830 — INFO — Processed and saved features for Crazy In Love.mp3 - 2PM. 5241 songs remaining.
# 2025-06-26 17:02:36,018 — INFO — Processed and saved features for Don't Stop Can't Stop.mp3 - 2PM. 5240 songs remaining.
# 2025-06-26 17:02:48,473 — INFO — Processed and saved features for Eien - Lasting heart.mp3 - 2PM. 5239 songs remaining.
# 2025-06-26 17:03:03,520 — INFO — Processed and saved features for Electricity (220V Mix).mp3 - 2PM. 5238 songs remaining.
# 2025-06-26 17:03:15,765 — INFO — Processed and saved features for Everybody.mp3 - 2PM. 5237 songs remaining.
# 2025-06-26 17:03:26,669 — INFO — Processed and saved features for Falling In Love.mp3 - 2PM. 5236 songs remaining.
# 2025-06-26 17:03:41,194 — INFO — Processed and saved features for Falling in Love (Instrumental).mp3 - 2PM. 5235 songs remaining.
# 2025-06-26 17:03:54,222 — INFO — Processed and saved features for Fight (Instrumental).mp3 - 2PM. 5234 songs remaining.
# 2025-06-26 17:04:05,212 — INFO — Processed and saved features for Fight.mp3 - 2PM. 5233 songs remaining.
# 2025-06-26 17:04:20,270 — INFO — Processed and saved features for Forever (Instrumental).mp3 - 2PM. 5232 songs remaining.
# 2025-06-26 17:04:35,667 — INFO — Processed and saved features for Forever.mp3 - 2PM. 5231 songs remaining.
# 2025-06-26 17:04:49,614 — INFO — Processed and saved features for Freeze.mp3 - 2PM. 5230 songs remaining.
# 2025-06-26 17:05:03,456 — INFO — Processed and saved features for GIVE ME LOVE.mp3 - 2PM. 5229 songs remaining.
# 2025-06-26 17:05:12,928 — INFO — Processed and saved features for Genesis.mp3 - 2PM. 5228 songs remaining.
# 2025-06-26 17:05:25,515 — INFO — Processed and saved features for Give Me Love (ArmySlick's Bavtronic Mix).mp3 - 2PM. 5227 songs remaining.
# 2025-06-26 17:05:38,429 — INFO — Processed and saved features for Give Me Love (Instrumental).mp3 - 2PM. 5226 songs remaining.
# 2025-06-26 17:05:50,086 — INFO — Processed and saved features for Guilty Love (Instrumental).mp3 - 2PM. 5225 songs remaining.
# 2025-06-26 17:06:01,560 — INFO — Processed and saved features for Guilty Love.mp3 - 2PM. 5224 songs remaining.
# 2025-06-26 17:06:12,835 — INFO — Processed and saved features for HIGHER.mp3 - 2PM. 5223 songs remaining.
# 2025-06-26 17:06:28,861 — INFO — Processed and saved features for Hanareteitemo (Live).mp3 - 2PM. 5222 songs remaining.
# 2025-06-26 17:06:42,396 — INFO — Processed and saved features for Hanareteitemo.mp3 - 2PM. 5221 songs remaining.
# 2025-06-26 17:06:54,560 — INFO — Processed and saved features for Hands Up (East4A Mix).mp3 - 2PM. 5220 songs remaining.
# 2025-06-26 17:07:06,010 — INFO — Processed and saved features for Hands Up (Japanese Ver.).mp3 - 2PM. 5219 songs remaining.
# 2025-06-26 17:07:18,098 — INFO — Processed and saved features for Heartbeat (Japanese Ver. (Without Main Vocal) (Original Karaoke)).mp3 - 2PM. 5218 songs remaining.
# 2025-06-26 17:07:31,111 — INFO — Processed and saved features for Heartbeat (Japanese Ver.).mp3 - 2PM. 5217 songs remaining.
# 2025-06-26 17:07:44,427 — INFO — Processed and saved features for Heartbeat (Red Light Mix).mp3 - 2PM. 5216 songs remaining.
# 2025-06-26 17:08:01,988 — INFO — Processed and saved features for Higher (Instrumental).mp3 - 2PM. 5215 songs remaining.
# 2025-06-26 17:08:14,087 — INFO — Processed and saved features for Hyakunichikinenbi.mp3 - 2PM. 5214 songs remaining.
# 2025-06-26 17:08:26,777 — INFO — Processed and saved features for I Can't.mp3 - 2PM. 5213 songs remaining.
# 2025-06-26 17:08:38,167 — INFO — Processed and saved features for I Hate You (Lounge Mix).mp3 - 2PM. 5212 songs remaining.
# 2025-06-26 17:08:52,444 — INFO — Processed and saved features for I know.mp3 - 2PM. 5211 songs remaining.
# 2025-06-26 17:09:05,717 — INFO — Processed and saved features for I want you.mp3 - 2PM. 5210 songs remaining.
# 2025-06-26 17:09:17,118 — INFO — Processed and saved features for I'll Be Back (Club Mix).mp3 - 2PM. 5209 songs remaining.
# 2025-06-26 17:09:30,798 — INFO — Processed and saved features for I'll Be Back (Japanese Ver. (Without Main Vocal) (Original Karaoke)).mp3 - 2PM. 5208 songs remaining.
# 2025-06-26 17:09:43,941 — INFO — Processed and saved features for I'll Be Back (Japanese Ver.).mp3 - 2PM. 5207 songs remaining.
# 2025-06-26 17:09:56,047 — INFO — Processed and saved features for I'll Be Back.mp3 - 2PM. 5206 songs remaining.
# 2025-06-26 17:10:08,208 — INFO — Processed and saved features for I'll Be OK.mp3 - 2PM. 5205 songs remaining.
# 2025-06-26 17:10:18,614 — INFO — Processed and saved features for I'm Your Man (Without Main Vocal - Original Karaoke).mp3 - 2PM. 5204 songs remaining.
# 2025-06-26 17:10:30,563 — INFO — Processed and saved features for I'm Your Man.mp3 - 2PM. 5203 songs remaining.
# 2025-06-26 17:10:39,871 — INFO — Processed and saved features for Intro..mp3 - 2PM. 5202 songs remaining.
# 2025-06-26 17:10:49,317 — INFO — Processed and saved features for Intro.mp3 - 2PM. 5201 songs remaining.
# 2025-06-26 17:11:03,353 — INFO — Processed and saved features for Jam Session.mp3 - 2PM. 5200 songs remaining.
# 2025-06-26 17:11:16,830 — INFO — Processed and saved features for Kimigaireba ((Without Main Vocal) [Instrumental]).mp3 - 2PM. 5199 songs remaining.
# 2025-06-26 17:11:28,127 — INFO — Processed and saved features for Kimigaireba.mp3 - 2PM. 5198 songs remaining.
# 2025-06-26 17:11:39,704 — INFO — Processed and saved features for Make it -Japanese version- (HotSauce Remix).mp3 - 2PM. 5197 songs remaining.
# 2025-06-26 17:11:51,674 — INFO — Processed and saved features for Make it -Japanese version-.mp3 - 2PM. 5196 songs remaining.
# 2025-06-26 17:12:06,211 — INFO — Processed and saved features for Masquerade (ArmySlick's Bavtronic Mix).mp3 - 2PM. 5195 songs remaining.
# 2025-06-26 17:12:19,556 — INFO — Processed and saved features for Masquerade (Instrumental).mp3 - 2PM. 5194 songs remaining.
# 2025-06-26 17:12:31,751 — INFO — Processed and saved features for Masquerade (Legend of 2PM Version).mp3 - 2PM. 5193 songs remaining.
# 2025-06-26 17:12:43,619 — INFO — Processed and saved features for Masquerade.mp3 - 2PM. 5192 songs remaining.
# 2025-06-26 17:13:00,308 — INFO — Processed and saved features for Maybe She'll Come Back (Bossa Nova Mix).mp3 - 2PM. 5191 songs remaining.
# 2025-06-26 17:13:11,614 — INFO — Processed and saved features for Mayday.mp3 - 2PM. 5190 songs remaining.
# 2025-06-26 17:13:24,688 — INFO — Processed and saved features for Merry-go-round.mp3 - 2PM. 5189 songs remaining.
# 2025-06-26 17:13:36,541 — INFO — Processed and saved features for Midaretemina (Instrumental).mp3 - 2PM. 5188 songs remaining.
# 2025-06-26 17:13:50,364 — INFO — Processed and saved features for Missing You.mp3 - 2PM. 5187 songs remaining.
# 2025-06-26 17:14:05,607 — INFO — Processed and saved features for Moon & Back.mp3 - 2PM. 5186 songs remaining.
# 2025-06-26 17:14:17,117 — INFO — Processed and saved features for My House (Japanese Version [Without Main Vocal]).mp3 - 2PM. 5185 songs remaining.
# 2025-06-26 17:14:28,715 — INFO — Processed and saved features for My House (Japanese Version).mp3 - 2PM. 5184 songs remaining.
# 2025-06-26 17:14:39,474 — INFO — Processed and saved features for My House -Japanese version- (Acoustic Version).mp3 - 2PM. 5183 songs remaining.
# 2025-06-26 17:14:53,819 — INFO — Processed and saved features for NEXT Generation.mp3 - 2PM. 5182 songs remaining.
# 2025-06-26 17:15:06,928 — INFO — Processed and saved features for Only Girl.mp3 - 2PM. 5181 songs remaining.
# 2025-06-26 17:15:19,400 — INFO — Processed and saved features for Only One.mp3 - 2PM. 5180 songs remaining.
# 2025-06-26 17:15:32,422 — INFO — Processed and saved features for Only You (Acoustic Mix).mp3 - 2PM. 5179 songs remaining.
# 2025-06-26 17:15:44,801 — INFO — Processed and saved features for Party Monster.mp3 - 2PM. 5178 songs remaining.
# 2025-06-26 17:15:57,561 — INFO — Processed and saved features for Promise (I'll be) (Japanese Version).mp3 - 2PM. 5177 songs remaining.
# 2025-06-26 17:16:11,263 — INFO — Processed and saved features for SOS Man.mp3 - 2PM. 5176 songs remaining.
# 2025-06-26 17:16:24,154 — INFO — Processed and saved features for Set Me Free.mp3 - 2PM. 5175 songs remaining.
# 2025-06-26 17:16:38,008 — INFO — Processed and saved features for Sexy Ladies.mp3 - 2PM. 5174 songs remaining.
# 2025-06-26 17:16:48,368 — INFO — Processed and saved features for Shining Star.mp3 - 2PM. 5173 songs remaining.
# 2025-06-26 17:17:01,659 — INFO — Processed and saved features for Shiny Girl.mp3 - 2PM. 5172 songs remaining.
# 2025-06-26 17:17:14,032 — INFO — Processed and saved features for Slender Man.mp3 - 2PM. 5171 songs remaining.
# 2025-06-26 17:17:25,915 — INFO — Processed and saved features for So Bad.mp3 - 2PM. 5170 songs remaining.
# 2025-06-26 17:17:38,313 — INFO — Processed and saved features for Souzou site mite.mp3 - 2PM. 5169 songs remaining.
# 2025-06-26 17:17:52,768 — INFO — Processed and saved features for Stay Here (Instrumental).mp3 - 2PM. 5168 songs remaining.
# 2025-06-26 17:18:06,313 — INFO — Processed and saved features for Stay Here.mp3 - 2PM. 5167 songs remaining.
# 2025-06-26 17:18:17,736 — INFO — Processed and saved features for Stay With Me.mp3 - 2PM. 5166 songs remaining.
# 2025-06-26 17:18:28,982 — INFO — Processed and saved features for Step by Step.mp3 - 2PM. 5165 songs remaining.
# 2025-06-26 17:18:43,395 — INFO — Processed and saved features for TEASER.mp3 - 2PM. 5164 songs remaining.
# 2025-06-26 17:18:56,444 — INFO — Processed and saved features for Take Off (Without Main Vocal - Original Karaoke).mp3 - 2PM. 5163 songs remaining.
# 2025-06-26 17:19:07,605 — INFO — Processed and saved features for Take Off.mp3 - 2PM. 5162 songs remaining.
# 2025-06-26 17:19:22,648 — INFO — Processed and saved features for Talk about Your Love.mp3 - 2PM. 5161 songs remaining.
# 2025-06-26 17:19:33,918 — INFO — Processed and saved features for The Galaxy.mp3 - 2PM. 5160 songs remaining.
# 2025-06-26 17:19:43,220 — INFO — Processed and saved features for The Legend.mp3 - 2PM. 5159 songs remaining.
# 2025-06-26 17:19:56,233 — INFO — Processed and saved features for This Is Love.mp3 - 2PM. 5158 songs remaining.
# 2025-06-26 17:20:11,293 — INFO — Processed and saved features for Through the Fire.mp3 - 2PM. 5157 songs remaining.
# 2025-06-26 17:20:24,356 — INFO — Processed and saved features for URAHARA.mp3 - 2PM. 5156 songs remaining.
# 2025-06-26 17:20:36,566 — INFO — Processed and saved features for Ultra Lover (Without Main Vocal(Original Karaoke)).mp3 - 2PM. 5155 songs remaining.
# 2025-06-26 17:20:49,082 — INFO — Processed and saved features for Ultra Lover.mp3 - 2PM. 5154 songs remaining.
# 2025-06-26 17:21:01,039 — INFO — Processed and saved features for Unmei.mp3 - 2PM. 5153 songs remaining.
# 2025-06-26 17:21:13,534 — INFO — Processed and saved features for WITH ME AGAIN (taalthechoi Remix).mp3 - 2PM. 5152 songs remaining.
# 2025-06-26 17:21:26,911 — INFO — Processed and saved features for WITH ME AGAIN.mp3 - 2PM. 5151 songs remaining.
# 2025-06-26 17:21:40,351 — INFO — Processed and saved features for WOW.mp3 - 2PM. 5150 songs remaining.
# 2025-06-26 17:21:51,622 — INFO — Processed and saved features for Want You Back.mp3 - 2PM. 5149 songs remaining.
# 2025-06-26 17:22:05,220 — INFO — Processed and saved features for Wasurenaide.mp3 - 2PM. 5148 songs remaining.
# 2025-06-26 17:22:18,376 — INFO — Processed and saved features for Winter Games (Instrumental).mp3 - 2PM. 5147 songs remaining.
# 2025-06-26 17:22:32,361 — INFO — Processed and saved features for Winter Games.mp3 - 2PM. 5146 songs remaining.
# 2025-06-26 17:22:46,123 — INFO — Processed and saved features for Without U (Explorer Mix).mp3 - 2PM. 5145 songs remaining.
# 2025-06-26 17:23:02,835 — INFO — Processed and saved features for Without U (Japanese Ver. (Without Main Vocal) (Original Karaoke)).mp3 - 2PM. 5144 songs remaining.
# 2025-06-26 17:23:14,572 — INFO — Processed and saved features for Without U (Japanese Ver.).mp3 - 2PM. 5143 songs remaining.
# 2025-06-26 17:23:25,473 — INFO — Processed and saved features for Without U.mp3 - 2PM. 5142 songs remaining.
# 2025-06-26 17:23:39,024 — INFO — Processed and saved features for amano gawa GALAXY.mp3 - 2PM. 5141 songs remaining.
# 2025-06-26 17:23:52,781 — INFO — Processed and saved features for harukaze good bye again.mp3 - 2PM. 5140 songs remaining.
# 2025-06-26 17:24:07,925 — INFO — Processed and saved features for issyoni sugoshita jikan.mp3 - 2PM. 5139 songs remaining.
# 2025-06-26 17:24:20,438 — INFO — Processed and saved features for midaretemina.mp3 - 2PM. 5138 songs remaining.
# 2025-06-26 17:24:32,003 — INFO — Processed and saved features for 괜찮아 안 괜찮아 OK or Not.mp3 - 2PM. 5137 songs remaining.
# 2025-06-26 17:24:44,134 — INFO — Processed and saved features for 놓지 않을게 Hold You.mp3 - 2PM. 5136 songs remaining.
# 2025-06-26 17:24:56,099 — INFO — Processed and saved features for 둘이 Two of Us.mp3 - 2PM. 5135 songs remaining.
# 2025-06-26 17:25:07,677 — INFO — Processed and saved features for 보고싶어, 보러갈게 On My Way.mp3 - 2PM. 5134 songs remaining.
# 2025-06-26 17:25:19,947 — INFO — Processed and saved features for 샴페인 Champagne.mp3 - 2PM. 5133 songs remaining.
# 2025-06-26 17:25:30,980 — INFO — Processed and saved features for 우리집 My House (Acoustic ver.).mp3 - 2PM. 5132 songs remaining.
# 2025-06-26 17:25:45,337 — INFO — Processed and saved features for 집 앞 카페 The Cafe.mp3 - 2PM. 5131 songs remaining.
# 2025-06-26 17:25:56,966 — INFO — Processed and saved features for 해야 해 Make it.mp3 - 2PM. 5130 songs remaining.
# 2025-06-26 17:26:10,635 — INFO — Processed and saved features for Are You Dazed (멍하니).mp3 - Miss A. 5129 songs remaining.
# 2025-06-26 17:26:23,003 — INFO — Processed and saved features for Bad Girl Good Girl.mp3 - Miss A. 5128 songs remaining.
# 2025-06-26 17:26:36,490 — INFO — Processed and saved features for Break It.mp3 - Miss A. 5127 songs remaining.
# 2025-06-26 17:26:51,721 — INFO — Processed and saved features for Breathe.mp3 - Miss A. 5126 songs remaining.
# 2025-06-26 17:27:03,499 — INFO — Processed and saved features for Come Tonight (놀러와).mp3 - Miss A. 5125 songs remaining.
# 2025-06-26 17:27:15,669 — INFO — Processed and saved features for Good-bye Baby (Silver Mix).mp3 - Miss A. 5124 songs remaining.
# 2025-06-26 17:27:28,804 — INFO — Processed and saved features for Good-bye Baby.mp3 - Miss A. 5123 songs remaining.
# 2025-06-26 17:27:41,018 — INFO — Processed and saved features for Help Me.mp3 - Miss A. 5122 songs remaining.
# 2025-06-26 17:27:52,284 — INFO — Processed and saved features for Hide & Sick.mp3 - Miss A. 5121 songs remaining.
# 2025-06-26 17:28:06,226 — INFO — Processed and saved features for Hush (Party Ver.).mp3 - Miss A. 5120 songs remaining.
# 2025-06-26 17:28:18,215 — INFO — Processed and saved features for Hush.mp3 - Miss A. 5119 songs remaining.
# 2025-06-26 17:28:32,003 — INFO — Processed and saved features for I Caught Ya.mp3 - Miss A. 5118 songs remaining.
# 2025-06-26 17:28:43,167 — INFO — Processed and saved features for If I Were a Boy.mp3 - Miss A. 5117 songs remaining.
# 2025-06-26 17:28:56,126 — INFO — Processed and saved features for Like U.mp3 - Miss A. 5116 songs remaining.
# 2025-06-26 17:29:09,754 — INFO — Processed and saved features for Lips.mp3 - Miss A. 5115 songs remaining.
# 2025-06-26 17:29:22,381 — INFO — Processed and saved features for Love Again (다시 사랑).mp3 - Miss A. 5114 songs remaining.
# 2025-06-26 17:29:34,636 — INFO — Processed and saved features for Love Alone.mp3 - Miss A. 5113 songs remaining.
# 2025-06-26 17:29:47,856 — INFO — Processed and saved features for Love Is U.mp3 - Miss A. 5112 songs remaining.
# 2025-06-26 17:30:01,637 — INFO — Processed and saved features for Love Song.mp3 - Miss A. 5111 songs remaining.
# 2025-06-26 17:30:13,933 — INFO — Processed and saved features for Ma Style.mp3 - Miss A. 5110 songs remaining.
# 2025-06-26 17:30:27,181 — INFO — Processed and saved features for Madness (Feat. Tacyeon).mp3 - Miss A. 5109 songs remaining.
# 2025-06-26 17:30:39,426 — INFO — Processed and saved features for Meet Again (딱 마주쳐).mp3 - Miss A. 5108 songs remaining.
# 2025-06-26 17:30:50,786 — INFO — Processed and saved features for Mr. Johnny.mp3 - Miss A. 5107 songs remaining.
# 2025-06-26 17:31:04,487 — INFO — Processed and saved features for No Mercy.mp3 - Miss A. 5106 songs remaining.
# 2025-06-26 17:31:16,337 — INFO — Processed and saved features for Over U.mp3 - Miss A. 5105 songs remaining.
# 2025-06-26 17:31:28,392 — INFO — Processed and saved features for Play That Music, DJ (그 음악을 틀어줘요 DJ).mp3 - Miss A. 5104 songs remaining.
# ...
# 2025-06-27 13:18:43,721 — INFO — Processed and saved features for DARARI (ROCK Remix) (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 114 songs remaining.
# 2025-06-27 13:18:55,580 — INFO — Processed and saved features for DARARI (ROCK Remix) (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 113 songs remaining.
# 2025-06-27 13:19:08,408 — INFO — Processed and saved features for DARARI (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 112 songs remaining.
# 2025-06-27 13:19:21,520 — INFO — Processed and saved features for DARARI.mp3 - Treasure. 111 songs remaining.
# 2025-06-27 13:19:34,333 — INFO — Processed and saved features for G.O.A.T (CHOI HYUN SUK × YOSHI × HARUTO Unit) (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 110 songs remaining.
# 2025-06-27 13:19:46,862 — INFO — Processed and saved features for G.O.A.T (Rap Unit) feat. 이영현 (LEE YOUNG HYUN).mp3 - Treasure. 109 songs remaining.
# 2025-06-27 13:20:05,296 — INFO — Processed and saved features for GOING CRAZY (Remix) + B.L.T (BLING LIKE THIS) (Remix) + ORANGE (Remix) (TREASURE JAPAN TOUR....mp3 - Treasure. 108 songs remaining.
# 2025-06-27 13:20:18,049 — INFO — Processed and saved features for GOING CRAZY (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 107 songs remaining.
# 2025-06-27 13:20:29,264 — INFO — Processed and saved features for HELLO -JP Ver.- (2024 TREASURE FAN MEETING~WONDERLAND~).mp3 - Treasure. 106 songs remaining.
# 2025-06-27 13:20:41,527 — INFO — Processed and saved features for HELLO -JP Ver.- (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 105 songs remaining.
# 2025-06-27 13:20:53,655 — INFO — Processed and saved features for HELLO -JP Ver.-.mp3 - Treasure. 104 songs remaining.
# 2025-06-27 13:21:05,833 — INFO — Processed and saved features for HELLO -JP Ver.‐ (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 103 songs remaining.
# 2025-06-27 13:21:18,575 — INFO — Processed and saved features for HELLO.mp3 - Treasure. 102 songs remaining.
# 2025-06-27 13:21:30,849 — INFO — Processed and saved features for HOLD IT IN (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 101 songs remaining.
# 2025-06-27 13:21:42,222 — INFO — Processed and saved features for HOLD IT IN (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 100 songs remaining.
# 2025-06-27 13:21:54,309 — INFO — Processed and saved features for HOLD IT IN -JP Ver.-.mp3 - Treasure. 99 songs remaining.
# 2025-06-27 13:22:06,600 — INFO — Processed and saved features for HOLD IT IN.mp3 - Treasure. 98 songs remaining.
# 2025-06-27 13:22:19,912 — INFO — Processed and saved features for Here I Stand (2024 TREASURE FAN MEETING~WONDERLAND~).mp3 - Treasure. 97 songs remaining.
# 2025-06-27 13:22:32,438 — INFO — Processed and saved features for Here I Stand (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 96 songs remaining.
# 2025-06-27 13:22:45,981 — INFO — Processed and saved features for Here I Stand (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 95 songs remaining.
# 2025-06-27 13:22:56,426 — INFO — Processed and saved features for Here I Stand -Anime Edit-.mp3 - Treasure. 94 songs remaining.
# 2025-06-27 13:23:12,088 — INFO — Processed and saved features for Here I Stand.mp3 - Treasure. 93 songs remaining.
# 2025-06-27 13:23:26,846 — INFO — Processed and saved features for I LOVE YOU -JP Ver.- (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 92 songs remaining.
# 2025-06-27 13:23:39,383 — INFO — Processed and saved features for I LOVE YOU -JP Ver.- (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 91 songs remaining.
# 2025-06-27 13:23:51,411 — INFO — Processed and saved features for I LOVE YOU.mp3 - Treasure. 90 songs remaining.
# 2025-06-27 13:24:02,560 — INFO — Processed and saved features for I WANT YOUR LOVE (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 89 songs remaining.
# 2025-06-27 13:24:14,831 — INFO — Processed and saved features for I WANT YOUR LOVE.mp3 - Treasure. 88 songs remaining.
# 2025-06-27 13:24:28,020 — INFO — Processed and saved features for IT’S OKAY (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 87 songs remaining.
# 2025-06-27 13:24:40,920 — INFO — Processed and saved features for IT’S OKAY.mp3 - Treasure. 86 songs remaining.
# 2025-06-27 13:24:52,483 — INFO — Processed and saved features for JIKJIN -JP Ver.- (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 85 songs remaining.
# 2025-06-27 13:25:06,876 — INFO — Processed and saved features for JIKJIN -JP Ver.- (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 84 songs remaining.
# 2025-06-27 13:25:17,570 — INFO — Processed and saved features for JIKJIN.mp3 - Treasure. 83 songs remaining.
# 2025-06-27 13:25:29,226 — INFO — Processed and saved features for KING KONG (2024 TREASURE FAN MEETING~WONDERLAND~).mp3 - Treasure. 82 songs remaining.
# 2025-06-27 13:25:40,388 — INFO — Processed and saved features for KING KONG -JP Ver.-.mp3 - Treasure. 81 songs remaining.
# 2025-06-27 13:25:51,751 — INFO — Processed and saved features for KING KONG.mp3 - Treasure. 80 songs remaining.
# 2025-06-27 13:26:03,405 — INFO — Processed and saved features for LAST NIGHT -JP Ver.-.mp3 - Treasure. 79 songs remaining.
# 2025-06-27 13:26:14,865 — INFO — Processed and saved features for LAST NIGHT.mp3 - Treasure. 78 songs remaining.
# 2025-06-27 13:26:27,303 — INFO — Processed and saved features for LET IT BURN (2024 TREASURE FAN MEETING~WONDERLAND~).mp3 - Treasure. 77 songs remaining.
# 2025-06-27 13:26:40,296 — INFO — Processed and saved features for LET IT BURN (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 76 songs remaining.
# 2025-06-27 13:26:52,747 — INFO — Processed and saved features for LET IT BURN.mp3 - Treasure. 75 songs remaining.
# 2025-06-27 13:27:05,614 — INFO — Processed and saved features for MMM (Rock Ver.) -JP Ver.- (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 74 songs remaining.
# 2025-06-27 13:27:17,716 — INFO — Processed and saved features for MMM (Rock Ver.) -JP Ver.- (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 73 songs remaining.
# 2025-06-27 13:27:29,738 — INFO — Processed and saved features for MMM.mp3 - Treasure. 72 songs remaining.
# 2025-06-27 13:27:42,594 — INFO — Processed and saved features for MOVE (T5) (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 71 songs remaining.
# 2025-06-27 13:27:55,574 — INFO — Processed and saved features for MOVE (T5) -JP ver.-.mp3 - Treasure. 70 songs remaining.
# 2025-06-27 13:28:10,697 — INFO — Processed and saved features for MOVE (T5).mp3 - Treasure. 69 songs remaining.
# 2025-06-27 13:28:22,222 — INFO — Processed and saved features for MY TREASURE -JP Ver.- (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 68 songs remaining.
# 2025-06-27 13:28:35,811 — INFO — Processed and saved features for MY TREASURE -JP Ver.‐ (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 67 songs remaining.
# 2025-06-27 13:28:49,055 — INFO — Processed and saved features for MY TREASURE.mp3 - Treasure. 66 songs remaining.
# 2025-06-27 13:29:02,855 — INFO — Processed and saved features for ORANGE (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 65 songs remaining.
# 2025-06-27 13:29:15,605 — INFO — Processed and saved features for REVERSE (2024 TREASURE FAN MEETING~WONDERLAND~).mp3 - Treasure. 64 songs remaining.
# 2025-06-27 13:29:25,416 — INFO — Processed and saved features for REVERSE - Drama Edit -.mp3 - Treasure. 63 songs remaining.
# 2025-06-27 13:29:37,781 — INFO — Processed and saved features for REVERSE.mp3 - Treasure. 62 songs remaining.
# 2025-06-27 13:29:49,472 — INFO — Processed and saved features for RHYTHM TA REMIX (Rock Ver.) (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 61 songs remaining.
# 2025-06-27 13:30:01,995 — INFO — Processed and saved features for RUN (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 60 songs remaining.
# 2025-06-27 13:30:14,650 — INFO — Processed and saved features for RUN.mp3 - Treasure. 59 songs remaining.
# 2025-06-27 13:30:27,356 — INFO — Processed and saved features for SARURU.mp3 - Treasure. 58 songs remaining.
# 2025-06-27 13:30:41,514 — INFO — Processed and saved features for SLOWMOTION (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 57 songs remaining.
# 2025-06-27 13:30:53,824 — INFO — Processed and saved features for SLOWMOTION.mp3 - Treasure. 56 songs remaining.
# 2025-06-27 13:31:05,772 — INFO — Processed and saved features for STUPID (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 55 songs remaining.
# 2025-06-27 13:31:17,441 — INFO — Processed and saved features for STUPID -JP Ver.-.mp3 - Treasure. 54 songs remaining.
# 2025-06-27 13:31:29,806 — INFO — Processed and saved features for THANK YOU (ASAHI x HARUTO Unit).mp3 - Treasure. 53 songs remaining.
# 2025-06-27 13:31:43,971 — INFO — Processed and saved features for THE WAY TO (JIHOON × JUNKYU × PARK JEONG WOO Unit) (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 52 songs remaining.
# 2025-06-27 13:31:55,216 — INFO — Processed and saved features for U (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 51 songs remaining.
# 2025-06-27 13:32:07,082 — INFO — Processed and saved features for U.mp3 - Treasure. 50 songs remaining.
# 2025-06-27 13:32:17,613 — INFO — Processed and saved features for VolKno (CHOI HYUN SUK x YOSHI x HARUTO Unit) (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 49 songs remaining.
# 2025-06-27 13:32:29,785 — INFO — Processed and saved features for VolKno (CHOI HYUN SUK x YOSHI x HARUTO Unit) (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in....mp3 - Treasure. 48 songs remaining.
# 2025-06-27 13:32:41,928 — INFO — Processed and saved features for VolKno (CHOI HYUN SUK x YOSHI x HARUTO Unit) -JP Ver.-.mp3 - Treasure. 47 songs remaining.
# 2025-06-27 13:32:56,689 — INFO — Processed and saved features for VolKno (CHOI HYUN SUK x YOSHI x HARUTO Unit).mp3 - Treasure. 46 songs remaining.
# 2025-06-27 13:33:12,910 — INFO — Processed and saved features for WHATEVER, WHENEVER.mp3 - Treasure. 45 songs remaining.
# 2025-06-27 13:33:24,784 — INFO — Processed and saved features for WONDERLAND (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 44 songs remaining.
# 2025-06-27 13:33:37,693 — INFO — Processed and saved features for WONDERLAND.mp3 - Treasure. 43 songs remaining.
# 2025-06-27 13:33:48,555 — INFO — Processed and saved features for YELLOW -JP Ver.-.mp3 - Treasure. 42 songs remaining.
# 2025-06-27 13:33:59,846 — INFO — Processed and saved features for YELLOW.mp3 - Treasure. 41 songs remaining.
# 2025-06-27 13:34:11,420 — INFO — Processed and saved features for ありがとう (ASAHI x HARUTO Unit) (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 40 songs remaining.
# 2025-06-27 13:34:24,296 — INFO — Processed and saved features for ありがとう (ASAHI x HARUTO Unit) (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA....mp3 - Treasure. 39 songs remaining.
# 2025-06-27 13:34:36,288 — INFO — Processed and saved features for ありがとう (ASAHI x HARUTO Unit) -JP Ver.-.mp3 - Treasure. 38 songs remaining.
# 2025-06-27 13:34:50,378 — INFO — Processed and saved features for オレンジ (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 37 songs remaining.
# 2025-06-27 13:35:04,094 — INFO — Processed and saved features for オレンジ.mp3 - Treasure. 36 songs remaining.
# 2025-06-27 13:35:17,190 — INFO — Processed and saved features for ミチョガネ.mp3 - Treasure. 35 songs remaining.
# 2025-06-27 13:35:29,432 — INFO — Processed and saved features for 病 (2024 TREASURE TOUR [REBOOT] IN JAPAN).mp3 - Treasure. 34 songs remaining.
# 2025-06-27 13:35:41,820 — INFO — Processed and saved features for 病 (TREASURE JAPAN TOUR 2022-23 ~HELLO~ SPECIAL in KYOCERA DOME OSAKA).mp3 - Treasure. 33 songs remaining.
# 2025-06-27 13:35:54,215 — INFO — Processed and saved features for 病.mp3 - Treasure. 32 songs remaining.
# 2025-06-27 13:36:06,708 — INFO — Processed and saved features for 괜찮아질 거야 (IT’S OKAY).mp3 - Treasure. 31 songs remaining.
# 2025-06-27 13:36:18,609 — INFO — Processed and saved features for 나랑 있자 (BE WITH ME).mp3 - Treasure. 30 songs remaining.
# 2025-06-27 13:36:32,221 — INFO — Processed and saved features for 다라리 (DARARI).mp3 - Treasure. 29 songs remaining.
# 2025-06-27 13:36:45,363 — INFO — Processed and saved features for 들어와 (Come To Me).mp3 - Treasure. 28 songs remaining.
# 2025-06-27 13:36:57,639 — INFO — Processed and saved features for 멍청이 (STUPID).mp3 - Treasure. 27 songs remaining.
# 2025-06-27 13:37:10,396 — INFO — Processed and saved features for 미쳐가네 (Going Crazy).mp3 - Treasure. 26 songs remaining.
# 2025-06-27 13:37:21,769 — INFO — Processed and saved features for 병 (LOVESICK).mp3 - Treasure. 25 songs remaining.
# 2025-06-27 13:37:33,585 — INFO — Processed and saved features for 사랑해 (I Love You).mp3 - Treasure. 24 songs remaining.
# 2025-06-27 13:37:46,473 — INFO — Processed and saved features for 어른 (THE WAY TO) (VOCAL Unit).mp3 - Treasure. 23 songs remaining.
# 2025-06-27 13:37:59,825 — INFO — Processed and saved features for 오렌지 (Orange).mp3 - Treasure. 22 songs remaining.
# 2025-06-27 13:38:14,818 — INFO — Processed and saved features for 음 (MMM).mp3 - Treasure. 21 songs remaining.
# 2025-06-27 13:38:25,859 — INFO — Processed and saved features for 직진 (JIKJIN).mp3 - Treasure. 20 songs remaining.
# 2025-06-27 13:38:39,163 — INFO — Processed and saved features for BATTER UP (7 ver.).mp3 - BabyMonster. 19 songs remaining.
# 2025-06-27 13:38:50,478 — INFO — Processed and saved features for BATTER UP (Remix) - Bonus Track.mp3 - BabyMonster. 18 songs remaining.
# 2025-06-27 13:39:01,209 — INFO — Processed and saved features for BATTER UP -JP Version.mp3 - BabyMonster. 17 songs remaining.
# 2025-06-27 13:39:13,347 — INFO — Processed and saved features for BATTER UP.mp3 - BabyMonster. 16 songs remaining.
# 2025-06-27 13:39:25,513 — INFO — Processed and saved features for BILLIONAIRE.mp3 - BabyMonster. 15 songs remaining.
# 2025-06-27 13:39:36,780 — INFO — Processed and saved features for CLIK CLAK.mp3 - BabyMonster. 14 songs remaining.
# 2025-06-27 13:39:48,690 — INFO — Processed and saved features for DREAM.mp3 - BabyMonster. 13 songs remaining.
# 2025-06-27 13:40:01,539 — INFO — Processed and saved features for DRIP.mp3 - BabyMonster. 12 songs remaining.
# 2025-06-27 13:40:17,065 — INFO — Processed and saved features for FOREVER.mp3 - BabyMonster. 11 songs remaining.
# 2025-06-27 13:40:29,526 — INFO — Processed and saved features for Ghost.mp3 - BabyMonster. 10 songs remaining.
# 2025-06-27 13:40:40,739 — INFO — Processed and saved features for LIKE THAT.mp3 - BabyMonster. 9 songs remaining.
# 2025-06-27 13:40:53,323 — INFO — Processed and saved features for Love In My Heart.mp3 - BabyMonster. 8 songs remaining.
# 2025-06-27 13:41:04,788 — INFO — Processed and saved features for Love, Maybe.mp3 - BabyMonster. 7 songs remaining.
# 2025-06-27 13:41:12,990 — INFO — Processed and saved features for MONSTERS (Intro).mp3 - BabyMonster. 6 songs remaining.
# 2025-06-27 13:41:26,003 — INFO — Processed and saved features for Really Like You.mp3 - BabyMonster. 5 songs remaining.
# 2025-06-27 13:41:37,385 — INFO — Processed and saved features for SHEESH.mp3 - BabyMonster. 4 songs remaining.
# 2025-06-27 13:41:51,307 — INFO — Processed and saved features for Stuck In The Middle (7 ver.).mp3 - BabyMonster. 3 songs remaining.
# 2025-06-27 13:42:03,486 — INFO — Processed and saved features for Stuck In The Middle (Remix).mp3 - BabyMonster. 2 songs remaining.
# 2025-06-27 13:42:16,068 — INFO — Processed and saved features for Stuck In The Middle.mp3 - BabyMonster. 1 songs remaining.
# 2025-06-27 13:42:27,215 — INFO — Processed and saved features for Woke Up In Tokyo (RUKA & ASA).mp3 - BabyMonster. 0 songs remaining.
